# %% [markdown]
# # Objective
# The purpose of this notebook is to create a unified dataset of landfast ice extent for the Alaskan coastline from the Mahoney / InteRFACE data collection as described in the exploratory data analysis notebooks and the summary documentation thereof. The notebook is based on the SNAP Data Pipeline concept and template.
#
# ## Pipeline Steps
#
# The flow here is as follows:
#
#     0. Setup - define directories, intial conditions, etc. Execute the setup code cell before any other step
#     1. Fetch the data if it is currently not available locally
#     2. Create a DateTime index that encompasses the entire range of the data and gracefully handle that the atomic units of data here have variable ranges or "durations" on the order of 20 days. Also check that the turnover between calendar years is handled.
#     3. Map the existing data collection to this index.
#     4. For each item in the existing data collection constrain the valid array values and establish a common and well known spatial reference.
#     5. Create a merged raster from Chukchi and Beaufort data (or lackthereof) for each date in the time index with appropriate data types and NoData values.
#
# Creating the ultimate GeoTIFFs (step 5) will require understanding the four possibles cases of data availability for each date in our DateTime Index.
#
#     A: No data is available at all.
#     B: A single raster exists from only one region.
#     C: Multiple rasters exist from only one region.
#     D: One or more rasters exist from both regions.
#
# We can handle these cases like so:
#
#  - Case A: Skip these dates for now, there is no data available. These dates can be brought back into a datacube at a later time if needed.
#
#  - Case B: Take the single raster and merge it with the mask for whichever region has no data.
#
#  - Case C: Take all the rasters and create a 3D array of values, and filter for the maximum of the time index. Then merge these data with the mask for whichever region has no data.
#
#  - Case D. Same as above, but do the stacking and filtering for both regions, and then then merge those two outputs together.

# %% [markdown]
# ## 0 - Setup
#
# The following environment variables should be set before running this notebook:
# - `$SRC_DIR`: the base directory for storing project data that should be backed up.
# - `$DST_DIR`: the output directory where final products are placed.
# - `$SCRATCH_DIR`: scratch directory for storing project data which does not need to be backed up.
#
# I like to set these variables from within the notebook for clarity, but it could be done from your shell also.

# %%
# place all imports here
import config # this sets the GDAL and PROJ envs before importing geospatial libs
import os
import shutil
import re
import datetime
import pandas as pd
import rasterio as rio
import numpy as np
import pickle
import slurm
from pathlib import Path
from rasterio.crs import CRS
from rasterio.merge import merge
# local helper library, like clippy
import helpers as snappy
# constants
NCORES = 1
SLURM_MAIL = "cparr4@alaska.edu"
AC_CONDA_ENV = "/home/UA/cparr4/miniconda3/envs/conda-project"
COPY_SOURCE = False
project_dir = os.getcwd()


# set the environment variables and create directories and Path objects
os.environ["BASE_DIR"] = "/workspace/Data/Base_Data/Cryosphere/landfast_seaice"
src_p = Path(os.environ["BASE_DIR"])

os.environ["DST_DIR"] = "/atlas_scratch/cparr4/landfast_seaice/mahoney_preprocess/outputs"
dst_p = Path(os.environ["DST_DIR"]).mkdir(parents=True, exist_ok=True)
dst_p = Path(os.environ["DST_DIR"])

os.environ["SCRATCH_DIR"] = "/atlas_scratch/cparr4/landfast_seaice/mahoney_preprocess/scratch"
scratch_p = Path(os.environ["SCRATCH_DIR"]).mkdir(parents=True, exist_ok=True)
scratch_p = Path(os.environ["SCRATCH_DIR"])

# create scratch directory copied and renamed source GeoTIFFs
copy_dir = scratch_p.joinpath("src_copy")
copy_dir.mkdir(exist_ok=True, parents=True)

# create scratch directory for slurm scripts
slurm_dir = scratch_p.joinpath("slurm")
slurm_dir.mkdir(exist_ok=True, parents=True)

# create scratch directory for GeoTIFFs with corrected array values
arrfix_dir = scratch_p.joinpath("arrfix")
arrfix_dir.mkdir(exist_ok=True, parents=True)

# create scratch directory for regional mask or "dummy" GeoTIFFs
mask_dir = scratch_p.joinpath("mask")
mask_dir.mkdir(exist_ok=True, parents=True)

# create scratch directory for max-filtered GeoTIFFs to handle Cases C and D
max_dir = scratch_p.joinpath("max")
max_dir.mkdir(exist_ok=True, parents=True)

snappy.t_out = open("/dev/stdout", "w")
snappy.jprint("Executing pipeline Step 0 (setup)\n")
snappy.jprint(f"SRC_DIR set to {src_p}")
snappy.jprint(f"DST_DIR set to {dst_p}")
snappy.jprint(f"SCRATCH_DIR set to {scratch_p}\n")
snappy.jprint("Pipeline Step 0 (setup) complete\n")
snappy.jprint("Current snapshot of the working directories:")
_ = os.system("cd $SCRATCH_DIR/.. && tree -d")
# Out:
# Executing pipeline Step 0 (setup)
#
# SRC_DIR set to /workspace/Data/Base_Data/Cryosphere/landfast_seaice
# DST_DIR set to /atlas_scratch/cparr4/landfast_seaice/mahoney_preprocess/outputs
# SCRATCH_DIR set to /atlas_scratch/cparr4/landfast_seaice/mahoney_preprocess/scratch
#
# Pipeline Step 0 (setup) complete
#
# Current snapshot of the working directories:
# .
# ├── outputs
# └── scratch
#     ├── arrfix
#     ├── mask
#     ├── max
#     ├── slurm
#     └── src_copy
#
# 7 directories

# %% [markdown]
# ## 1 - Fetch
#
# We don't have to download any data - these are on our file system. We'll use the fetch stage to point at the data and create the list of filenames we'll use. We can also copy the source data to our scratch directory and do a file name clean up.

# %%
snappy.jprint("Executing pipeline Step 1 (fetch)\n")

slie_fps = [x for x in src_p.rglob("*_slie.tif")]
n_src_fps = len(slie_fps)
new_fps = [copy_dir / ''.join(x.parent.parent.name.lower() + "_" + x.name) for x in slie_fps]

if COPY_SOURCE:
    for src, dst in zip(slie_fps, new_fps):
        shutil.copy(src, dst)

snappy.jprint(f"Source data consists of {n_src_fps} Geotiffs, for example:")
snappy.jprint(slie_fps[0])

n_copied_fps = len([x for x in copy_dir.rglob("*_slie.tif")])

assert(n_src_fps == n_copied_fps)

snappy.jprint("Pipeline Step 1 complete\n")
# Out:
# Executing pipeline Step 1 (fetch)
#
# Source data consists of 566 Geotiffs, for example:
# /workspace/Data/Base_Data/Cryosphere/landfast_seaice/Beaufort/2000-01/r2000_286-311_slie.tif
# Pipeline Step 1 complete

# %% [markdown]
# ## 2 - Create Time Index
#
# We'll write a few functions to parse file names and convert day-of-year (DOY) style dates to a more readable and DateTime friendly YYYY-MM-DD format. The file names are of the style `chukchi_r2007_326-350_slie.tif`. We'll construct a lookup where we can see all the date information associated with each file. We need to be aware that negative durations are lurking where we jump to the next calendar year.
#
# Once those durations are fixed and all the date information is in place we can establish the start and end dates of the entire collection and create a DateTime index that encompasses all the data.

# %%
snappy.jprint("Executing pipeline Step 2 (time index)\n")

def create_regional_fp(fp):
    """Construct a new filename that contains the region info."""
    new_fp = dst_p / ''.join(fp.parent.parent.name.lower() + "_" + fp.name)
    return new_fp
    

def get_doy(fp):
    """Fetch the DOY range from a file name."""
    try:
        doy = re.match(r'.*([0-3][0-9][0-9]-[0-3][0-9][0-9])', fp).group(1)
    except:
        doy = re.match(r'.*([0-3][0-9][0-9]_[0-3][0-9][0-9])', fp).group(1)
        doy = doy.replace("_", "-")
    return doy


def get_re_year(fp):
    """Fetch a single year (YYYY) from a file name."""
    year = re.match(r'.*([1-3][0-9]{3})', fp).group(1)
    return int(year)


def split_doy(doy_range):
    """Split a DOY range string into a integer start and end."""
    doy_start, doy_end = doy_range.split("-")
    return int(doy_start), int(doy_end)    


def doy_date_to_YYYYMMDD(year, days):
    """Convert a a DOY + Year date to a YYYY-MM-DD datetime object."""
    dt = datetime.datetime(year, 1, 1) + datetime.timedelta(days - 1)
    return dt


di = {}
for fp in slie_fps:
    
    k = create_regional_fp(fp).name
    di[k] = {}
    di[k]["start_year"] = get_re_year(k)
    di[k]["doy_range"] = get_doy(k)
    di[k]["doy_start"], di[k]["doy_end"] = split_doy(di[k]["doy_range"])
    di[k]["dt_start"] = doy_date_to_YYYYMMDD(di[k]["start_year"], di[k]["doy_start"])
    di[k]["dt_end"] = doy_date_to_YYYYMMDD(di[k]["start_year"], di[k]["doy_end"])
    di[k]["dt_duration"] = di[k]["dt_end"] - di[k]["dt_start"]

snappy.jprint("Example of a lookup with an incorrect duration:\n")
snappy.jprint(di['beaufort_r2000_349-003_slie.tif'])

def set_end_year(di):
    """Adds an end year for each file and handles rollover cases."""
    for k in di.keys():
        if di[k]["dt_duration"].days < 0:
            di[k]["end_year"] = di[k]["start_year"] + 1
            di[k]["dt_end"] = doy_date_to_YYYYMMDD(di[k]["end_year"], di[k]["doy_end"])
            di[k]["dt_duration"] = di[k]["dt_end"] - di[k]["dt_start"]

        else:
            di[k]["end_year"] = di[k]["start_year"]


set_end_year(di)
snappy.jprint("\n")
snappy.jprint("Example of a lookup with a corrected duration:\n")
snappy.jprint(di['beaufort_r2000_349-003_slie.tif'])


def get_first_dt(di):
    """Get the earliest chronological start date from the lookup."""
    start_dts = []
    for k in di.keys():
        start_dts.append(di[k]["dt_start"])
    start_dt = sorted(start_dts)[0]
    return start_dt


def get_last_dt(di):
    """Get the latest chronological end date from the lookup."""
    end_dts = []
    for k in di.keys():
        end_dts.append(di[k]["dt_end"])
    last_dt = sorted(end_dts)[-1]
    return last_dt

end = get_last_dt(di)
start = get_first_dt(di)
dt_range = pd.date_range(start=start, end=end)
snappy.jprint(f"\nEarliest chronological date is {start}\n")
snappy.jprint(f"Latest chronological date is {end}\n")
snappy.jprint("Pipeline Step 2 complete\n")
# Out:
# Executing pipeline Step 2 (time index)
#
# Example of a lookup with an incorrect duration:
#
# {'start_year': 2000, 'doy_range': '349-003', 'doy_start': 349, 'doy_end': 3, 'dt_start': datetime.datetime(2000, 12, 14, 0, 0), 'dt_end': datetime.datetime(2000, 1, 3, 0, 0), 'dt_duration': datetime.timedelta(days=-346)}
#
#
# Example of a lookup with a corrected duration:
#
# {'start_year': 2000, 'doy_range': '349-003', 'doy_start': 349, 'doy_end': 3, 'dt_start': datetime.datetime(2000, 12, 14, 0, 0), 'dt_end': datetime.datetime(2001, 1, 3, 0, 0), 'dt_duration': datetime.timedelta(days=20), 'end_year': 2001}
#
# Earliest chronological date is 1996-10-17 00:00:00
#
# Latest chronological date is 2008-07-14 00:00:00
#
# Pipeline Step 2 complete

# %% [markdown]
# ## 3 - Map Existing Data to the Time Index
#
# Because each file spans many days, a single calendar day can be represented by more than one raster. We need to map dates to the representative rasters by checking if the date is in the time range represented by the file. We'll want to know how many files match from the Beaufort region, how many from the Chukchi region, and how many match total. We also expect that some calendar days will have no matches at all (e.g., August, which is not in the seasonal ice cycle). We'll create a new lookup keyed by each date in the DateTime Index that stores the above information and the matching file names.
#
# Some individual days are represented by as many as six rasters across both regions! We'll stash some pickle files to indicate which dates correspond to which cases described in the introduction.

# %%
def time_in_range(start, end, x):
    """Return true if x is in the range [start, end]"""
    if start <= end:
        return start <= x <= end
    else:
        return start <= x or x <= end

dt_di = {}

for dt in dt_range:
    dt_di[dt] = {}
    dt_di[dt]["matching data"] = []
    beaufort_count = 0
    chukchi_count = 0
    
    for k in di.keys():
        if time_in_range(di[k]["dt_start"], di[k]["dt_end"], dt):
            dt_di[dt]["matching data"].append(k)
            
            if "beaufort" in k.lower():
                beaufort_count += 1
            if "chukchi" in k.lower():
                chukchi_count += 1
            
    if len(dt_di[dt]["matching data"]) == 0:
        dt_di[dt]["matching data"].append("no data")
    
    dt_di[dt]["beaufort_count"] = beaufort_count
    dt_di[dt]["chukchi_count"] = chukchi_count
    dt_di[dt]["match_count"] = chukchi_count + beaufort_count
    
df = pd.DataFrame.from_dict(dt_di).T

snappy.jprint("\nSample of mapping data to a time stamp:\n")
snappy.jprint(df.sort_values("match_count", ascending=False).iloc[1])

conditions = [
    (df["match_count"] == 0),
    (df["match_count"] == 1),
    ((df["match_count"] > 1) & (df["chukchi_count"] * df["beaufort_count"] == 0)),
    ((df["match_count"] > 1) & (df["chukchi_count"] * df["beaufort_count"] != 0))]
choices = [1, 2, 3, 4] # these map to A, B, C, and D
df["merge_case"] = np.select(conditions, choices)

snappy.jprint("\nSummary of merge cases - most have data from both regions which is good.\n")
snappy.jprint(df["merge_case"].value_counts())
snappy.jprint("Writing pickles of each merge case to use in processing functions called by slurm.")

merge_case_b = df[df.merge_case == 2]
dt_arr_di_case_b = merge_case_b.T.to_dict()
with open(max_dir / "single_raster_single_region.pickle", "wb") as handle:
    pickle.dump(dt_arr_di_case_b, handle, protocol=pickle.HIGHEST_PROTOCOL)

merge_case_c = df[df.merge_case == 3]
dt_arr_di_case_c = merge_case_c.T.to_dict()
with open(max_dir / "many_raster_single_region.pickle", "wb") as handle:
    pickle.dump(dt_arr_di_case_c, handle, protocol=pickle.HIGHEST_PROTOCOL)

merge_case_d = df[df.merge_case == 4]
dt_arr_di_case_d = merge_case_d.T.to_dict()
with open(max_dir / "many_raster_both_regions.pickle", "wb") as handle:
    pickle.dump(dt_arr_di_case_d, handle, protocol=pickle.HIGHEST_PROTOCOL)

snappy.jprint("\nPipeline Step 3 complete\n")
# Out:
# Sample of mapping data to a time stamp:
#
# matching data     [beaufort_r2006_058-084_slie.tif, beaufort_r20...
# beaufort_count                                                    3
# chukchi_count                                                     3
# match_count                                                       6
# Name: 2006-03-23 00:00:00, dtype: object
#
# Summary of merge cases - most have data from both regions which is good.
#
# 4    2510
# 3     829
# 1     797
# 2     153
# Name: merge_case, dtype: int64
# Writing pickles of each merge case to use in processing functions called by slurm.
#
# Pipeline Step 3 complete

# %% [markdown]
# ## 4 - Constrain and Fix the Array Values, Spatial References, and Generate Masks
#
# The next step is to constrain our array values to a known range. We know from our EDA work the value schema in the existing collection is as follows:
#
#  - 0: No landfast sea ice is present for this pixel. This means either water, or sea-ice that is NOT landfast.
#  - 255: landfast sea ice is present for this pixel
#  - 128: A landmask.
#  - 63, 64, other oddball values: NoData
#
# These values can be reduced to binary set where `0` indicates the absence of landfast sea ice and `1` the presence of it.
#
# We'll define a function (see `fix_raster_values.py`) that forces this array value mapping and writes a new GeoTIFF.
#
# Also, at this stage we can also create cohesive spatial references and raster creation profiles. Ultimately we want to create a merged raster as well, so we'll create three new rasters and raster profiles:
# 1. An empty mask (all zeros) for the Chukchi Region
# 2. An empty mask (all zeros) for the Beaufort Region
# 3. An empty mask (all zeros) for the combined Chukchi and Beaufort regions
#
# Once we have established cohesive raster profiles, we can generate the function arguments that will be used to consolidate the array values. The fixed output GeoTIFFs will just have an "arrfix" prefix and be stashed in the `scratch/arrfix` directory.

# %%
snappy.jprint("Executing pipeline Step 4 (fix the array values and spatial references and generate masks)\n")

# create cohesive raster profiles
beauf_sample = new_fps[0]
chuk_sample = new_fps[-1]

with rio.open(beauf_sample) as beauf_src:
    beauf_src = rio.open(beauf_sample)
    beauf_profile = beauf_src.profile
beauf_profile["crs"] = CRS.from_epsg(3338)
beauf_profile.update(compress="lzw")

with rio.open(chuk_sample):
    chuk_src = rio.open(chuk_sample)
    chuk_profile = chuk_src.profile
chuk_profile["crs"] = CRS.from_epsg(3338)
chuk_profile.update(compress="lzw")

arr_merge, aff_merge = merge([beauf_src, chuk_src])

new_profile = chuk_profile.copy()
new_profile["height"], new_profile["width"] = arr_merge[0].shape
new_profile["transform"] = aff_merge
new_profile["crs"] = CRS.from_epsg(3338)
new_profile.update(compress="lzw")

with open(mask_dir / "beaufort_raster_profile.pickle", "wb") as handle:
    pickle.dump(beauf_profile, handle, protocol=pickle.HIGHEST_PROTOCOL)
with open(mask_dir / "chukchi_raster_profile.pickle", "wb") as handle:
    pickle.dump(chuk_profile, handle, protocol=pickle.HIGHEST_PROTOCOL)
with open(mask_dir / "both_region_profile.pickle", "wb") as handle:
    pickle.dump(new_profile, handle, protocol=pickle.HIGHEST_PROTOCOL)

# generate the masks and write to disk
with rio.open(mask_dir / "both_region_mask.tif", 'w', **new_profile) as dst:
        dst.write(np.zeros(arr_merge[0].shape), 1)

with rio.open(mask_dir / "beaufort_mask.tif", 'w', **beauf_profile) as dst:
        dst.write(np.zeros((beauf_profile["height"], beauf_profile["width"])), 1)

with rio.open(mask_dir / "chukchi_mask.tif", 'w', **chuk_profile) as dst:
        dst.write(np.zeros((chuk_profile["height"], chuk_profile["width"])), 1)
        
# we want the mask paths for later
both_mask_fp = mask_dir / "both_region_mask.tif"
chuk_mask_fp = mask_dir / "chukchi_mask.tif"
beauf_mask_fp = mask_dir / "beaufort_mask.tif"

# nice to indicate when data are written to disk
mask_fps = list(mask_dir.glob('*'))
snappy.jprint(f"{len(mask_fps)} files written to {mask_dir}")

snappy.jprint("\nGenerating Slurm scripts to correct the raster values and write new GeoTIFFs.")

# write slurm scripts to fix the raster values of an individual file
project_dir = os.getcwd()

chuk_fps = list(copy_dir.glob("chukchi*"))
chuk_pkl = mask_dir / "chukchi_raster_profile.pickle" 
beauf_fps = list(copy_dir.glob("beaufort*"))
beauf_pkl = mask_dir / "beaufort_raster_profile.pickle" 


chuk_slurm_fps = [
    slurm.write_sbatch(
        NCORES, SLURM_MAIL, slurm_dir, AC_CONDA_ENV, fp, chuk_pkl, project_dir, arrfix_dir
    ) 
    for fp in chuk_fps
]

snappy.jprint(f"\n{len(chuk_slurm_fps)} slurm scripts for the Chukchi written to {slurm_dir}")
snappy.jprint("\nExecuting Chukchi slurm scripts with sbatch...")

# Call the slurm scripts with the `sbatch` command
_ = [os.system(f"sbatch {fp}") for fp in chuk_slurm_fps]

snappy.jprint(f"\n{len(chuk_slurm_fps)} slurm scripts for the Beaufort written to {slurm_dir}")
snappy.jprint("\nExecuting Beaufort slurm scripts with sbatch...\n")
beaufort_slurm_fps = [
    slurm.write_sbatch(
        NCORES, SLURM_MAIL, slurm_dir, AC_CONDA_ENV, fp, beauf_pkl, project_dir, arrfix_dir
    ) 
    for fp in beauf_fps
]

_ = [os.system(f"sbatch {fp}") for fp in beaufort_slurm_fps]

snappy.jprint("Pipeline Step 4 complete\n")
# Out:
# Executing pipeline Step 4 (fix the array values and spatial references and generate masks)
#
# 6 files written to /atlas_scratch/cparr4/landfast_seaice/mahoney_preprocess/scratch/mask
#
# Generating Slurm scripts to correct the raster values and write new GeoTIFFs.
#
# 316 slurm scripts for the Chukchi written to /atlas_scratch/cparr4/landfast_seaice/mahoney_preprocess/scratch/slurm
#
# Executing Chukchi slurm scripts with sbatch...
# Submitted batch job 3893967
# Submitted batch job 3893968
# Submitted batch job 3893969
# Submitted batch job 3893970
# Submitted batch job 3893971
# Submitted batch job 3893972
# Submitted batch job 3893973
# Submitted batch job 3893974
# Submitted batch job 3893975
# Submitted batch job 3893976
# Submitted batch job 3893977
# Submitted batch job 3893978
# Submitted batch job 3893979
# Submitted batch job 3893980
# Submitted batch job 3893981
# Submitted batch job 3893982
# Submitted batch job 3893983
# Submitted batch job 3893984
# Submitted batch job 3893985
# Submitted batch job 3893986
# Submitted batch job 3893987
# Submitted batch job 3893988
# Submitted batch job 3893989
# Submitted batch job 3893990
# Submitted batch job 3893991
# Submitted batch job 3893992
# Submitted batch job 3893993
# Submitted batch job 3893994
# Submitted batch job 3893995
# Submitted batch job 3893996
# Submitted batch job 3893997
# Submitted batch job 3893998
# Submitted batch job 3893999
# Submitted batch job 3894000
# Submitted batch job 3894001
# Submitted batch job 3894002
# Submitted batch job 3894003
# Submitted batch job 3894004
# Submitted batch job 3894005
# Submitted batch job 3894006
# Submitted batch job 3894007
# Submitted batch job 3894008
# Submitted batch job 3894009
# Submitted batch job 3894010
# Submitted batch job 3894011
# Submitted batch job 3894012
# Submitted batch job 3894013
# Submitted batch job 3894014
# Submitted batch job 3894015
# Submitted batch job 3894016
# Submitted batch job 3894017
# Submitted batch job 3894018
# Submitted batch job 3894019
# Submitted batch job 3894020
# Submitted batch job 3894021
# Submitted batch job 3894022
# Submitted batch job 3894023
# Submitted batch job 3894024
# Submitted batch job 3894025
# Submitted batch job 3894026
# Submitted batch job 3894027
# Submitted batch job 3894028
# Submitted batch job 3894029
# Submitted batch job 3894030
# Submitted batch job 3894031
# Submitted batch job 3894032
# Submitted batch job 3894033
# Submitted batch job 3894034
# Submitted batch job 3894035
# Submitted batch job 3894036
# Submitted batch job 3894037
# Submitted batch job 3894038
# Submitted batch job 3894039
# Submitted batch job 3894040
# Submitted batch job 3894041
# Submitted batch job 3894042
# Submitted batch job 3894043
# Submitted batch job 3894044
# Submitted batch job 3894045
# Submitted batch job 3894046
# Submitted batch job 3894047
# Submitted batch job 3894048
# Submitted batch job 3894049
# Submitted batch job 3894050
# Submitted batch job 3894051
# Submitted batch job 3894052
# Submitted batch job 3894053
# Submitted batch job 3894054
# Submitted batch job 3894055
# Submitted batch job 3894056
# Submitted batch job 3894057
# Submitted batch job 3894058
# Submitted batch job 3894059
# Submitted batch job 3894060
# Submitted batch job 3894061
# Submitted batch job 3894062
# Submitted batch job 3894063
# Submitted batch job 3894064
# Submitted batch job 3894065
# Submitted batch job 3894066
# Submitted batch job 3894067
# Submitted batch job 3894068
# Submitted batch job 3894069
# Submitted batch job 3894070
# Submitted batch job 3894071
# Submitted batch job 3894072
# Submitted batch job 3894073
# Submitted batch job 3894074
# Submitted batch job 3894075
# Submitted batch job 3894076
# Submitted batch job 3894077
# Submitted batch job 3894078
# Submitted batch job 3894079
# Submitted batch job 3894080
# Submitted batch job 3894081
# Submitted batch job 3894082
# Submitted batch job 3894083
# Submitted batch job 3894084
# Submitted batch job 3894085
# Submitted batch job 3894086
# Submitted batch job 3894087
# Submitted batch job 3894088
# Submitted batch job 3894089
# Submitted batch job 3894090
# Submitted batch job 3894091
# Submitted batch job 3894092
# Submitted batch job 3894093
# Submitted batch job 3894094
# Submitted batch job 3894095
# Submitted batch job 3894096
# Submitted batch job 3894097
# Submitted batch job 3894098
# Submitted batch job 3894099
# Submitted batch job 3894100
# Submitted batch job 3894101
# Submitted batch job 3894102
# Submitted batch job 3894103
# Submitted batch job 3894104
# Submitted batch job 3894105
# Submitted batch job 3894106
# Submitted batch job 3894107
# Submitted batch job 3894108
# Submitted batch job 3894109
# Submitted batch job 3894110
# Submitted batch job 3894111
# Submitted batch job 3894112
# Submitted batch job 3894113
# Submitted batch job 3894114
# Submitted batch job 3894115
# Submitted batch job 3894116
# Submitted batch job 3894117
# Submitted batch job 3894118
# Submitted batch job 3894119
# Submitted batch job 3894120
# Submitted batch job 3894121
# Submitted batch job 3894122
# Submitted batch job 3894123
# Submitted batch job 3894124
# Submitted batch job 3894125
# Submitted batch job 3894126
# Submitted batch job 3894127
# Submitted batch job 3894128
# Submitted batch job 3894129
# Submitted batch job 3894130
# Submitted batch job 3894131
# Submitted batch job 3894132
# Submitted batch job 3894133
# Submitted batch job 3894134
# Submitted batch job 3894135
# Submitted batch job 3894136
# Submitted batch job 3894137
# Submitted batch job 3894138
# Submitted batch job 3894139
# Submitted batch job 3894140
# Submitted batch job 3894141
# Submitted batch job 3894142
# Submitted batch job 3894143
# Submitted batch job 3894144
# Submitted batch job 3894145
# Submitted batch job 3894146
# Submitted batch job 3894147
# Submitted batch job 3894148
# Submitted batch job 3894149
# Submitted batch job 3894150
# Submitted batch job 3894151
# Submitted batch job 3894152
# Submitted batch job 3894153
# Submitted batch job 3894154
# Submitted batch job 3894155
# Submitted batch job 3894156
# Submitted batch job 3894157
# Submitted batch job 3894158
# Submitted batch job 3894159
# Submitted batch job 3894160
# Submitted batch job 3894161
# Submitted batch job 3894162
# Submitted batch job 3894163
# Submitted batch job 3894164
# Submitted batch job 3894165
# Submitted batch job 3894166
# Submitted batch job 3894167
# Submitted batch job 3894168
# Submitted batch job 3894169
# Submitted batch job 3894170
# Submitted batch job 3894171
# Submitted batch job 3894172
# Submitted batch job 3894173
# Submitted batch job 3894174
# Submitted batch job 3894175
# Submitted batch job 3894176
# Submitted batch job 3894177
# Submitted batch job 3894178
# Submitted batch job 3894179
# Submitted batch job 3894180
# Submitted batch job 3894181
# Submitted batch job 3894182
# Submitted batch job 3894183
# Submitted batch job 3894184
# Submitted batch job 3894185
# Submitted batch job 3894186
# Submitted batch job 3894187
# Submitted batch job 3894188
# Submitted batch job 3894189
# Submitted batch job 3894190
# Submitted batch job 3894191
# Submitted batch job 3894192
# Submitted batch job 3894193
# Submitted batch job 3894194
# Submitted batch job 3894195
# Submitted batch job 3894196
# Submitted batch job 3894197
# Submitted batch job 3894198
# Submitted batch job 3894199
# Submitted batch job 3894200
# Submitted batch job 3894201
# Submitted batch job 3894202
# Submitted batch job 3894203
# Submitted batch job 3894204
# Submitted batch job 3894205
# Submitted batch job 3894206
# Submitted batch job 3894207
# Submitted batch job 3894208
# Submitted batch job 3894209
# Submitted batch job 3894210
# Submitted batch job 3894211
# Submitted batch job 3894212
# Submitted batch job 3894213
# Submitted batch job 3894214
# Submitted batch job 3894215
# Submitted batch job 3894216
# Submitted batch job 3894217
# Submitted batch job 3894218
# Submitted batch job 3894219
# Submitted batch job 3894220
# Submitted batch job 3894221
# Submitted batch job 3894222
# Submitted batch job 3894223
# Submitted batch job 3894224
# Submitted batch job 3894225
# Submitted batch job 3894226
# Submitted batch job 3894227
# Submitted batch job 3894228
# Submitted batch job 3894229
# Submitted batch job 3894230
# Submitted batch job 3894231
# Submitted batch job 3894232
# Submitted batch job 3894233
# Submitted batch job 3894234
# Submitted batch job 3894235
# Submitted batch job 3894236
# Submitted batch job 3894237
# Submitted batch job 3894238
# Submitted batch job 3894239
# Submitted batch job 3894240
# Submitted batch job 3894241
# Submitted batch job 3894242
# Submitted batch job 3894243
# Submitted batch job 3894244
# Submitted batch job 3894245
# Submitted batch job 3894246
# Submitted batch job 3894247
# Submitted batch job 3894248
# Submitted batch job 3894249
# Submitted batch job 3894250
# Submitted batch job 3894251
# Submitted batch job 3894252
# Submitted batch job 3894253
# Submitted batch job 3894254
# Submitted batch job 3894255
# Submitted batch job 3894256
# Submitted batch job 3894257
# Submitted batch job 3894258
# Submitted batch job 3894259
# Submitted batch job 3894260
# Submitted batch job 3894261
# Submitted batch job 3894262
# Submitted batch job 3894263
# Submitted batch job 3894264
# Submitted batch job 3894265
# Submitted batch job 3894266
# Submitted batch job 3894267
# Submitted batch job 3894268
# Submitted batch job 3894269
# Submitted batch job 3894270
# Submitted batch job 3894271
# Submitted batch job 3894272
# Submitted batch job 3894273
# Submitted batch job 3894274
# Submitted batch job 3894275
# Submitted batch job 3894276
# Submitted batch job 3894277
# Submitted batch job 3894278
# Submitted batch job 3894279
# Submitted batch job 3894280
# Submitted batch job 3894281
# Submitted batch job 3894282
#
# 316 slurm scripts for the Beaufort written to /atlas_scratch/cparr4/landfast_seaice/mahoney_preprocess/scratch/slurm
#
# Executing Beaufort slurm scripts with sbatch...
#
# Submitted batch job 3894283
# Submitted batch job 3894284
# Submitted batch job 3894285
# Submitted batch job 3894286
# Submitted batch job 3894287
# Submitted batch job 3894288
# Submitted batch job 3894289
# Submitted batch job 3894290
# Submitted batch job 3894291
# Submitted batch job 3894292
# Submitted batch job 3894293
# Submitted batch job 3894294
# Submitted batch job 3894295
# Submitted batch job 3894296
# Submitted batch job 3894297
# Submitted batch job 3894298
# Submitted batch job 3894299
# Submitted batch job 3894300
# Submitted batch job 3894301
# Submitted batch job 3894302
# Submitted batch job 3894303
# Submitted batch job 3894304
# Submitted batch job 3894305
# Submitted batch job 3894306
# Submitted batch job 3894307
# Submitted batch job 3894308
# Submitted batch job 3894309
# Submitted batch job 3894310
# Submitted batch job 3894311
# Submitted batch job 3894312
# Submitted batch job 3894313
# Submitted batch job 3894314
# Submitted batch job 3894315
# Submitted batch job 3894316
# Submitted batch job 3894317
# Submitted batch job 3894318
# Submitted batch job 3894319
# Submitted batch job 3894320
# Submitted batch job 3894321
# Submitted batch job 3894322
# Submitted batch job 3894323
# Submitted batch job 3894324
# Submitted batch job 3894325
# Submitted batch job 3894326
# Submitted batch job 3894327
# Submitted batch job 3894328
# Submitted batch job 3894329
# Submitted batch job 3894330
# Submitted batch job 3894331
# Submitted batch job 3894332
# Submitted batch job 3894333
# Submitted batch job 3894334
# Submitted batch job 3894335
# Submitted batch job 3894336
# Submitted batch job 3894337
# Submitted batch job 3894338
# Submitted batch job 3894339
# Submitted batch job 3894340
# Submitted batch job 3894341
# Submitted batch job 3894342
# Submitted batch job 3894343
# Submitted batch job 3894344
# Submitted batch job 3894345
# Submitted batch job 3894346
# Submitted batch job 3894347
# Submitted batch job 3894348
# Submitted batch job 3894349
# Submitted batch job 3894350
# Submitted batch job 3894351
# Submitted batch job 3894352
# Submitted batch job 3894353
# Submitted batch job 3894354
# Submitted batch job 3894355
# Submitted batch job 3894356
# Submitted batch job 3894357
# Submitted batch job 3894358
# Submitted batch job 3894359
# Submitted batch job 3894360
# Submitted batch job 3894361
# Submitted batch job 3894362
# Submitted batch job 3894363
# Submitted batch job 3894364
# Submitted batch job 3894365
# Submitted batch job 3894366
# Submitted batch job 3894367
# Submitted batch job 3894368
# Submitted batch job 3894369
# Submitted batch job 3894370
# Submitted batch job 3894371
# Submitted batch job 3894372
# Submitted batch job 3894373
# Submitted batch job 3894374
# Submitted batch job 3894375
# Submitted batch job 3894376
# Submitted batch job 3894377
# Submitted batch job 3894378
# Submitted batch job 3894379
# Submitted batch job 3894380
# Submitted batch job 3894381
# Submitted batch job 3894382
# Submitted batch job 3894383
# Submitted batch job 3894384
# Submitted batch job 3894385
# Submitted batch job 3894386
# Submitted batch job 3894387
# Submitted batch job 3894388
# Submitted batch job 3894389
# Submitted batch job 3894390
# Submitted batch job 3894391
# Submitted batch job 3894392
# Submitted batch job 3894393
# Submitted batch job 3894394
# Submitted batch job 3894395
# Submitted batch job 3894396
# Submitted batch job 3894397
# Submitted batch job 3894398
# Submitted batch job 3894399
# Submitted batch job 3894400
# Submitted batch job 3894401
# Submitted batch job 3894402
# Submitted batch job 3894403
# Submitted batch job 3894404
# Submitted batch job 3894405
# Submitted batch job 3894406
# Submitted batch job 3894407
# Submitted batch job 3894408
# Submitted batch job 3894409
# Submitted batch job 3894410
# Submitted batch job 3894411
# Submitted batch job 3894412
# Submitted batch job 3894413
# Submitted batch job 3894414
# Submitted batch job 3894415
# Submitted batch job 3894416
# Submitted batch job 3894417
# Submitted batch job 3894418
# Submitted batch job 3894419
# Submitted batch job 3894420
# Submitted batch job 3894421
# Submitted batch job 3894422
# Submitted batch job 3894423
# Submitted batch job 3894424
# Submitted batch job 3894425
# Submitted batch job 3894426
# Submitted batch job 3894427
# Submitted batch job 3894428
# Submitted batch job 3894429
# Submitted batch job 3894430
# Submitted batch job 3894431
# Submitted batch job 3894432
# Submitted batch job 3894433
# Submitted batch job 3894434
# Submitted batch job 3894435
# Submitted batch job 3894436
# Submitted batch job 3894437
# Submitted batch job 3894438
# Submitted batch job 3894439
# Submitted batch job 3894440
# Submitted batch job 3894441
# Submitted batch job 3894442
# Submitted batch job 3894443
# Submitted batch job 3894444
# Submitted batch job 3894445
# Submitted batch job 3894446
# Submitted batch job 3894447
# Submitted batch job 3894448
# Submitted batch job 3894449
# Submitted batch job 3894450
# Submitted batch job 3894451
# Submitted batch job 3894452
# Submitted batch job 3894453
# Submitted batch job 3894454
# Submitted batch job 3894455
# Submitted batch job 3894456
# Submitted batch job 3894457
# Submitted batch job 3894458
# Submitted batch job 3894459
# Submitted batch job 3894460
# Submitted batch job 3894461
# Submitted batch job 3894462
# Submitted batch job 3894463
# Submitted batch job 3894464
# Submitted batch job 3894465
# Submitted batch job 3894466
# Submitted batch job 3894467
# Submitted batch job 3894468
# Submitted batch job 3894469
# Submitted batch job 3894470
# Submitted batch job 3894471
# Submitted batch job 3894472
# Submitted batch job 3894473
# Submitted batch job 3894474
# Submitted batch job 3894475
# Submitted batch job 3894476
# Submitted batch job 3894477
# Submitted batch job 3894478
# Submitted batch job 3894479
# Submitted batch job 3894480
# Submitted batch job 3894481
# Submitted batch job 3894482
# Submitted batch job 3894483
# Submitted batch job 3894484
# Submitted batch job 3894485
# Submitted batch job 3894486
# Submitted batch job 3894487
# Submitted batch job 3894488
# Submitted batch job 3894489
# Submitted batch job 3894490
# Submitted batch job 3894491
# Submitted batch job 3894492
# Submitted batch job 3894493
# Submitted batch job 3894494
# Submitted batch job 3894495
# Submitted batch job 3894496
# Submitted batch job 3894497
# Submitted batch job 3894498
# Submitted batch job 3894499
# Submitted batch job 3894500
# Submitted batch job 3894501
# Submitted batch job 3894502
# Submitted batch job 3894503
# Submitted batch job 3894504
# Submitted batch job 3894505
# Submitted batch job 3894506
# Submitted batch job 3894507
# Submitted batch job 3894508
# Submitted batch job 3894509
# Submitted batch job 3894510
# Submitted batch job 3894511
# Submitted batch job 3894512
# Submitted batch job 3894513
# Submitted batch job 3894514
# Submitted batch job 3894515
# Submitted batch job 3894516
# Submitted batch job 3894517
# Submitted batch job 3894518
# Submitted batch job 3894519
# Submitted batch job 3894520
# Submitted batch job 3894521
# Submitted batch job 3894522
# Submitted batch job 3894523
# Submitted batch job 3894524
# Submitted batch job 3894525
# Submitted batch job 3894526
# Submitted batch job 3894527
# Submitted batch job 3894528
# Submitted batch job 3894529
# Submitted batch job 3894530
# Submitted batch job 3894531
# Submitted batch job 3894532
# Pipeline Step 4 complete

# %%
n_fixed_fps = len([x for x in arrfix_dir.rglob("*.tif")])
assert(n_copied_fps == n_fixed_fps)

# %% [markdown]
# ## 5 - Create rasters that represent all possible data for a given date.
#
# This where we handle cases B, C, and D that we described earlier. The code that executes the logic of these cases (also described earlier) lives in the Python scripts that are slurmed.

# %%
snappy.jprint("Executing pipeline Step 5 (Create merged rasters)\n")

case_b_pkl = Path(max_dir / "single_raster_single_region.pickle")
case_b_slurm_dts = [
    slurm.write_case_b(
        NCORES, SLURM_MAIL, slurm_dir, AC_CONDA_ENV, case_b_pkl, k, project_dir, mask_dir, arrfix_dir, dst_p
    ) 
    for k in dt_arr_di_case_b.keys()
]
_ = [os.system(f"sbatch {x}") for x in case_b_slurm_dts]

case_c_pkl = Path(max_dir / "many_raster_single_region.pickle")
case_c_slurm_dts = [
    slurm.write_case_c(
        NCORES, SLURM_MAIL, slurm_dir, AC_CONDA_ENV, case_c_pkl, k, project_dir, mask_dir, max_dir, arrfix_dir, dst_p
    ) 
    for k in dt_arr_di_case_c.keys()
]
_ = [os.system(f"sbatch {x}") for x in case_c_slurm_dts]

case_d_pkl = Path(max_dir / "many_raster_both_regions.pickle")
case_d_slurm_dts = [
    slurm.write_case_d(
        NCORES, SLURM_MAIL, slurm_dir, AC_CONDA_ENV, case_d_pkl, k, project_dir, mask_dir, max_dir, arrfix_dir, dst_p
    ) 
    for k in dt_arr_di_case_d.keys()
]
_ = [os.system(f"sbatch {x}") for x in case_d_slurm_dts]

snappy.jprint("Pipeline Step 5 complete\n")
# Out:
# Executing pipeline Step 5 (Create merged rasters)
#
# Submitted batch job 3894533
# Submitted batch job 3894534
# Submitted batch job 3894535
# Submitted batch job 3894536
# Submitted batch job 3894537
# Submitted batch job 3894538
# Submitted batch job 3894539
# Submitted batch job 3894540
# Submitted batch job 3894541
# Submitted batch job 3894542
# Submitted batch job 3894543
# Submitted batch job 3894544
# Submitted batch job 3894545
# Submitted batch job 3894546
# Submitted batch job 3894547
# Submitted batch job 3894548
# Submitted batch job 3894549
# Submitted batch job 3894550
# Submitted batch job 3894551
# Submitted batch job 3894552
# Submitted batch job 3894553
# Submitted batch job 3894554
# Submitted batch job 3894555
# Submitted batch job 3894556
# Submitted batch job 3894557
# Submitted batch job 3894558
# Submitted batch job 3894559
# Submitted batch job 3894560
# Submitted batch job 3894561
# Submitted batch job 3894562
# Submitted batch job 3894563
# Submitted batch job 3894564
# Submitted batch job 3894565
# Submitted batch job 3894566
# Submitted batch job 3894567
# Submitted batch job 3894568
# Submitted batch job 3894569
# Submitted batch job 3894570
# Submitted batch job 3894571
# Submitted batch job 3894572
# Submitted batch job 3894573
# Submitted batch job 3894574
# Submitted batch job 3894575
# Submitted batch job 3894576
# Submitted batch job 3894577
# Submitted batch job 3894578
# Submitted batch job 3894579
# Submitted batch job 3894580
# Submitted batch job 3894581
# Submitted batch job 3894582
# Submitted batch job 3894583
# Submitted batch job 3894584
# Submitted batch job 3894585
# Submitted batch job 3894586
# Submitted batch job 3894587
# Submitted batch job 3894588
# Submitted batch job 3894589
# Submitted batch job 3894590
# Submitted batch job 3894591
# Submitted batch job 3894592
# Submitted batch job 3894593
# Submitted batch job 3894594
# Submitted batch job 3894595
# Submitted batch job 3894596
# Submitted batch job 3894597
# Submitted batch job 3894598
# Submitted batch job 3894599
# Submitted batch job 3894600
# Submitted batch job 3894601
# Submitted batch job 3894602
# Submitted batch job 3894603
# Submitted batch job 3894604
# Submitted batch job 3894605
# Submitted batch job 3894606
# Submitted batch job 3894607
# Submitted batch job 3894608
# Submitted batch job 3894609
# Submitted batch job 3894610
# Submitted batch job 3894611
# Submitted batch job 3894612
# Submitted batch job 3894613
# Submitted batch job 3894614
# Submitted batch job 3894615
# Submitted batch job 3894616
# Submitted batch job 3894617
# Submitted batch job 3894618
# Submitted batch job 3894619
# Submitted batch job 3894620
# Submitted batch job 3894621
# Submitted batch job 3894622
# Submitted batch job 3894623
# Submitted batch job 3894624
# Submitted batch job 3894625
# Submitted batch job 3894626
# Submitted batch job 3894627
# Submitted batch job 3894628
# Submitted batch job 3894629
# Submitted batch job 3894630
# Submitted batch job 3894631
# Submitted batch job 3894632
# Submitted batch job 3894633
# Submitted batch job 3894634
# Submitted batch job 3894635
# Submitted batch job 3894636
# Submitted batch job 3894637
# Submitted batch job 3894638
# Submitted batch job 3894639
# Submitted batch job 3894640
# Submitted batch job 3894641
# Submitted batch job 3894642
# Submitted batch job 3894643
# Submitted batch job 3894644
# Submitted batch job 3894645
# Submitted batch job 3894646
# Submitted batch job 3894647
# Submitted batch job 3894648
# Submitted batch job 3894649
# Submitted batch job 3894650
# Submitted batch job 3894651
# Submitted batch job 3894652
# Submitted batch job 3894653
# Submitted batch job 3894654
# Submitted batch job 3894655
# Submitted batch job 3894656
# Submitted batch job 3894657
# Submitted batch job 3894658
# Submitted batch job 3894659
# Submitted batch job 3894660
# Submitted batch job 3894661
# Submitted batch job 3894662
# Submitted batch job 3894663
# Submitted batch job 3894664
# Submitted batch job 3894665
# Submitted batch job 3894666
# Submitted batch job 3894667
# Submitted batch job 3894668
# Submitted batch job 3894669
# Submitted batch job 3894670
# Submitted batch job 3894671
# Submitted batch job 3894672
# Submitted batch job 3894673
# Submitted batch job 3894674
# Submitted batch job 3894675
# Submitted batch job 3894676
# Submitted batch job 3894677
# Submitted batch job 3894678
# Submitted batch job 3894679
# Submitted batch job 3894680
# Submitted batch job 3894681
# Submitted batch job 3894682
# Submitted batch job 3894683
# Submitted batch job 3894684
# Submitted batch job 3894685
# Submitted batch job 3894686
# Submitted batch job 3894687
# Submitted batch job 3894688
# Submitted batch job 3894689
# Submitted batch job 3894690
# Submitted batch job 3894691
# Submitted batch job 3894692
# Submitted batch job 3894693
# Submitted batch job 3894694
# Submitted batch job 3894695
# Submitted batch job 3894696
# Submitted batch job 3894697
# Submitted batch job 3894698
# Submitted batch job 3894699
# Submitted batch job 3894700
# Submitted batch job 3894701
# Submitted batch job 3894702
# Submitted batch job 3894703
# Submitted batch job 3894704
# Submitted batch job 3894705
# Submitted batch job 3894706
# Submitted batch job 3894707
# Submitted batch job 3894708
# Submitted batch job 3894709
# Submitted batch job 3894710
# Submitted batch job 3894711
# Submitted batch job 3894712
# Submitted batch job 3894713
# Submitted batch job 3894714
# Submitted batch job 3894715
# Submitted batch job 3894716
# Submitted batch job 3894717
# Submitted batch job 3894718
# Submitted batch job 3894719
# Submitted batch job 3894720
# Submitted batch job 3894721
# Submitted batch job 3894722
# Submitted batch job 3894723
# Submitted batch job 3894724
# Submitted batch job 3894725
# Submitted batch job 3894726
# Submitted batch job 3894727
# Submitted batch job 3894728
# Submitted batch job 3894729
# Submitted batch job 3894730
# Submitted batch job 3894731
# Submitted batch job 3894732
# Submitted batch job 3894733
# Submitted batch job 3894734
# Submitted batch job 3894735
# Submitted batch job 3894736
# Submitted batch job 3894737
# Submitted batch job 3894738
# Submitted batch job 3894739
# Submitted batch job 3894740
# Submitted batch job 3894741
# Submitted batch job 3894742
# Submitted batch job 3894743
# Submitted batch job 3894744
# Submitted batch job 3894745
# Submitted batch job 3894746
# Submitted batch job 3894747
# Submitted batch job 3894748
# Submitted batch job 3894749
# Submitted batch job 3894750
# Submitted batch job 3894751
# Submitted batch job 3894752
# Submitted batch job 3894753
# Submitted batch job 3894754
# Submitted batch job 3894755
# Submitted batch job 3894756
# Submitted batch job 3894757
# Submitted batch job 3894758
# Submitted batch job 3894759
# Submitted batch job 3894760
# Submitted batch job 3894761
# Submitted batch job 3894762
# Submitted batch job 3894763
# Submitted batch job 3894764
# Submitted batch job 3894765
# Submitted batch job 3894766
# Submitted batch job 3894767
# Submitted batch job 3894768
# Submitted batch job 3894769
# Submitted batch job 3894770
# Submitted batch job 3894771
# Submitted batch job 3894772
# Submitted batch job 3894773
# Submitted batch job 3894774
# Submitted batch job 3894775
# Submitted batch job 3894776
# Submitted batch job 3894777
# Submitted batch job 3894778
# Submitted batch job 3894779
# Submitted batch job 3894780
# Submitted batch job 3894781
# Submitted batch job 3894782
# Submitted batch job 3894783
# Submitted batch job 3894784
# Submitted batch job 3894785
# Submitted batch job 3894786
# Submitted batch job 3894787
# Submitted batch job 3894788
# Submitted batch job 3894789
# Submitted batch job 3894790
# Submitted batch job 3894791
# Submitted batch job 3894792
# Submitted batch job 3894793
# Submitted batch job 3894794
# Submitted batch job 3894795
# Submitted batch job 3894796
# Submitted batch job 3894797
# Submitted batch job 3894798
# Submitted batch job 3894799
# Submitted batch job 3894800
# Submitted batch job 3894801
# Submitted batch job 3894802
# Submitted batch job 3894803
# Submitted batch job 3894804
# Submitted batch job 3894805
# Submitted batch job 3894806
# Submitted batch job 3894807
# Submitted batch job 3894808
# Submitted batch job 3894809
# Submitted batch job 3894810
# Submitted batch job 3894811
# Submitted batch job 3894812
# Submitted batch job 3894813
# Submitted batch job 3894814
# Submitted batch job 3894815
# Submitted batch job 3894816
# Submitted batch job 3894817
# Submitted batch job 3894818
# Submitted batch job 3894819
# Submitted batch job 3894820
# Submitted batch job 3894821
# Submitted batch job 3894822
# Submitted batch job 3894823
# Submitted batch job 3894824
# Submitted batch job 3894825
# Submitted batch job 3894826
# Submitted batch job 3894827
# Submitted batch job 3894828
# Submitted batch job 3894829
# Submitted batch job 3894830
# Submitted batch job 3894831
# Submitted batch job 3894832
# Submitted batch job 3894833
# Submitted batch job 3894834
# Submitted batch job 3894835
# Submitted batch job 3894836
# Submitted batch job 3894837
# Submitted batch job 3894838
# Submitted batch job 3894839
# Submitted batch job 3894840
# Submitted batch job 3894841
# Submitted batch job 3894842
# Submitted batch job 3894843
# Submitted batch job 3894844
# Submitted batch job 3894845
# Submitted batch job 3894846
# Submitted batch job 3894847
# Submitted batch job 3894848
# Submitted batch job 3894849
# Submitted batch job 3894850
# Submitted batch job 3894851
# Submitted batch job 3894852
# Submitted batch job 3894853
# Submitted batch job 3894854
# Submitted batch job 3894855
# Submitted batch job 3894856
# Submitted batch job 3894857
# Submitted batch job 3894858
# Submitted batch job 3894859
# Submitted batch job 3894860
# Submitted batch job 3894861
# Submitted batch job 3894862
# Submitted batch job 3894863
# Submitted batch job 3894864
# Submitted batch job 3894865
# Submitted batch job 3894866
# Submitted batch job 3894867
# Submitted batch job 3894868
# Submitted batch job 3894869
# Submitted batch job 3894870
# Submitted batch job 3894871
# Submitted batch job 3894872
# Submitted batch job 3894873
# Submitted batch job 3894874
# Submitted batch job 3894875
# Submitted batch job 3894876
# Submitted batch job 3894877
# Submitted batch job 3894878
# Submitted batch job 3894879
# Submitted batch job 3894880
# Submitted batch job 3894881
# Submitted batch job 3894882
# Submitted batch job 3894883
# Submitted batch job 3894884
# Submitted batch job 3894885
# Submitted batch job 3894886
# Submitted batch job 3894887
# Submitted batch job 3894888
# Submitted batch job 3894889
# Submitted batch job 3894890
# Submitted batch job 3894891
# Submitted batch job 3894892
# Submitted batch job 3894893
# Submitted batch job 3894894
# Submitted batch job 3894895
# Submitted batch job 3894896
# Submitted batch job 3894897
# Submitted batch job 3894898
# Submitted batch job 3894899
# Submitted batch job 3894900
# Submitted batch job 3894901
# Submitted batch job 3894902
# Submitted batch job 3894903
# Submitted batch job 3894904
# Submitted batch job 3894905
# Submitted batch job 3894906
# Submitted batch job 3894907
# Submitted batch job 3894908
# Submitted batch job 3894909
# Submitted batch job 3894910
# Submitted batch job 3894911
# Submitted batch job 3894912
# Submitted batch job 3894913
# Submitted batch job 3894914
# Submitted batch job 3894915
# Submitted batch job 3894916
# Submitted batch job 3894917
# Submitted batch job 3894918
# Submitted batch job 3894919
# Submitted batch job 3894920
# Submitted batch job 3894921
# Submitted batch job 3894922
# Submitted batch job 3894923
# Submitted batch job 3894924
# Submitted batch job 3894925
# Submitted batch job 3894926
# Submitted batch job 3894927
# Submitted batch job 3894928
# Submitted batch job 3894929
# Submitted batch job 3894930
# Submitted batch job 3894931
# Submitted batch job 3894932
# Submitted batch job 3894933
# Submitted batch job 3894934
# Submitted batch job 3894935
# Submitted batch job 3894936
# Submitted batch job 3894937
# Submitted batch job 3894938
# Submitted batch job 3894939
# Submitted batch job 3894940
# Submitted batch job 3894941
# Submitted batch job 3894942
# Submitted batch job 3894943
# Submitted batch job 3894944
# Submitted batch job 3894945
# Submitted batch job 3894946
# Submitted batch job 3894947
# Submitted batch job 3894948
# Submitted batch job 3894949
# Submitted batch job 3894950
# Submitted batch job 3894951
# Submitted batch job 3894952
# Submitted batch job 3894953
# Submitted batch job 3894954
# Submitted batch job 3894955
# Submitted batch job 3894956
# Submitted batch job 3894957
# Submitted batch job 3894958
# Submitted batch job 3894959
# Submitted batch job 3894960
# Submitted batch job 3894961
# Submitted batch job 3894962
# Submitted batch job 3894963
# Submitted batch job 3894964
# Submitted batch job 3894965
# Submitted batch job 3894966
# Submitted batch job 3894967
# Submitted batch job 3894968
# Submitted batch job 3894969
# Submitted batch job 3894970
# Submitted batch job 3894971
# Submitted batch job 3894972
# Submitted batch job 3894973
# Submitted batch job 3894974
# Submitted batch job 3894975
# Submitted batch job 3894976
# Submitted batch job 3894977
# Submitted batch job 3894978
# Submitted batch job 3894979
# Submitted batch job 3894980
# Submitted batch job 3894981
# Submitted batch job 3894982
# Submitted batch job 3894983
# Submitted batch job 3894984
# Submitted batch job 3894985
# Submitted batch job 3894986
# Submitted batch job 3894987
# Submitted batch job 3894988
# Submitted batch job 3894989
# Submitted batch job 3894990
# Submitted batch job 3894991
# Submitted batch job 3894992
# Submitted batch job 3894993
# Submitted batch job 3894994
# Submitted batch job 3894995
# Submitted batch job 3894996
# Submitted batch job 3894997
# Submitted batch job 3894998
# Submitted batch job 3894999
# Submitted batch job 3895000
# Submitted batch job 3895001
# Submitted batch job 3895002
# Submitted batch job 3895003
# Submitted batch job 3895004
# Submitted batch job 3895005
# Submitted batch job 3895006
# Submitted batch job 3895007
# Submitted batch job 3895008
# Submitted batch job 3895009
# Submitted batch job 3895010
# Submitted batch job 3895011
# Submitted batch job 3895012
# Submitted batch job 3895013
# Submitted batch job 3895014
# Submitted batch job 3895015
# Submitted batch job 3895016
# Submitted batch job 3895017
# Submitted batch job 3895018
# Submitted batch job 3895019
# Submitted batch job 3895020
# Submitted batch job 3895021
# Submitted batch job 3895022
# Submitted batch job 3895023
# Submitted batch job 3895024
# Submitted batch job 3895025
# Submitted batch job 3895026
# Submitted batch job 3895027
# Submitted batch job 3895028
# Submitted batch job 3895029
# Submitted batch job 3895030
# Submitted batch job 3895031
# Submitted batch job 3895032
# Submitted batch job 3895033
# Submitted batch job 3895034
# Submitted batch job 3895035
# Submitted batch job 3895036
# Submitted batch job 3895037
# Submitted batch job 3895038
# Submitted batch job 3895039
# Submitted batch job 3895040
# Submitted batch job 3895041
# Submitted batch job 3895042
# Submitted batch job 3895043
# Submitted batch job 3895044
# Submitted batch job 3895045
# Submitted batch job 3895046
# Submitted batch job 3895047
# Submitted batch job 3895048
# Submitted batch job 3895049
# Submitted batch job 3895050
# Submitted batch job 3895051
# Submitted batch job 3895052
# Submitted batch job 3895053
# Submitted batch job 3895054
# Submitted batch job 3895055
# Submitted batch job 3895056
# Submitted batch job 3895057
# Submitted batch job 3895058
# Submitted batch job 3895059
# Submitted batch job 3895060
# Submitted batch job 3895061
# Submitted batch job 3895062
# Submitted batch job 3895063
# Submitted batch job 3895064
# Submitted batch job 3895065
# Submitted batch job 3895066
# Submitted batch job 3895067
# Submitted batch job 3895068
# Submitted batch job 3895069
# Submitted batch job 3895070
# Submitted batch job 3895071
# Submitted batch job 3895072
# Submitted batch job 3895073
# Submitted batch job 3895074
# Submitted batch job 3895075
# Submitted batch job 3895076
# Submitted batch job 3895077
# Submitted batch job 3895078
# Submitted batch job 3895079
# Submitted batch job 3895080
# ...
# Submitted batch job 3897455
# Submitted batch job 3897456
# Submitted batch job 3897457
# Submitted batch job 3897458
# Submitted batch job 3897459
# Submitted batch job 3897460
# Submitted batch job 3897461
# Submitted batch job 3897462
# Submitted batch job 3897463
# Submitted batch job 3897464
# Submitted batch job 3897465
# Submitted batch job 3897466
# Submitted batch job 3897467
# Submitted batch job 3897468
# Submitted batch job 3897469
# Submitted batch job 3897470
# Submitted batch job 3897471
# Submitted batch job 3897472
# Submitted batch job 3897473
# Submitted batch job 3897474
# Submitted batch job 3897475
# Submitted batch job 3897476
# Submitted batch job 3897477
# Submitted batch job 3897478
# Submitted batch job 3897479
# Submitted batch job 3897480
# Submitted batch job 3897481
# Submitted batch job 3897482
# Submitted batch job 3897483
# Submitted batch job 3897484
# Submitted batch job 3897485
# Submitted batch job 3897486
# Submitted batch job 3897487
# Submitted batch job 3897488
# Submitted batch job 3897489
# Submitted batch job 3897490
# Submitted batch job 3897491
# Submitted batch job 3897492
# Submitted batch job 3897493
# Submitted batch job 3897494
# Submitted batch job 3897495
# Submitted batch job 3897496
# Submitted batch job 3897497
# Submitted batch job 3897498
# Submitted batch job 3897499
# Submitted batch job 3897500
# Submitted batch job 3897501
# Submitted batch job 3897502
# Submitted batch job 3897503
# Submitted batch job 3897504
# Submitted batch job 3897505
# Submitted batch job 3897506
# Submitted batch job 3897507
# Submitted batch job 3897508
# Submitted batch job 3897509
# Submitted batch job 3897510
# Submitted batch job 3897511
# Submitted batch job 3897512
# Submitted batch job 3897513
# Submitted batch job 3897514
# Submitted batch job 3897515
# Submitted batch job 3897516
# Submitted batch job 3897517
# Submitted batch job 3897518
# Submitted batch job 3897519
# Submitted batch job 3897520
# Submitted batch job 3897521
# Submitted batch job 3897522
# Submitted batch job 3897523
# Submitted batch job 3897524
# Submitted batch job 3897525
# Submitted batch job 3897526
# Submitted batch job 3897527
# Submitted batch job 3897528
# Submitted batch job 3897529
# Submitted batch job 3897530
# Submitted batch job 3897531
# Submitted batch job 3897532
# Submitted batch job 3897533
# Submitted batch job 3897534
# Submitted batch job 3897535
# Submitted batch job 3897536
# Submitted batch job 3897537
# Submitted batch job 3897538
# Submitted batch job 3897539
# Submitted batch job 3897540
# Submitted batch job 3897541
# Submitted batch job 3897542
# Submitted batch job 3897543
# Submitted batch job 3897544
# Submitted batch job 3897545
# Submitted batch job 3897546
# Submitted batch job 3897547
# Submitted batch job 3897548
# Submitted batch job 3897549
# Submitted batch job 3897550
# Submitted batch job 3897551
# Submitted batch job 3897552
# Submitted batch job 3897553
# Submitted batch job 3897554
# Submitted batch job 3897555
# Submitted batch job 3897556
# Submitted batch job 3897557
# Submitted batch job 3897558
# Submitted batch job 3897559
# Submitted batch job 3897560
# Submitted batch job 3897561
# Submitted batch job 3897562
# Submitted batch job 3897563
# Submitted batch job 3897564
# Submitted batch job 3897565
# Submitted batch job 3897566
# Submitted batch job 3897567
# Submitted batch job 3897568
# Submitted batch job 3897569
# Submitted batch job 3897570
# Submitted batch job 3897571
# Submitted batch job 3897572
# Submitted batch job 3897573
# Submitted batch job 3897574
# Submitted batch job 3897575
# Submitted batch job 3897576
# Submitted batch job 3897577
# Submitted batch job 3897578
# Submitted batch job 3897579
# Submitted batch job 3897580
# Submitted batch job 3897581
# Submitted batch job 3897582
# Submitted batch job 3897583
# Submitted batch job 3897584
# Submitted batch job 3897585
# Submitted batch job 3897586
# Submitted batch job 3897587
# Submitted batch job 3897588
# Submitted batch job 3897589
# Submitted batch job 3897590
# Submitted batch job 3897591
# Submitted batch job 3897592
# Submitted batch job 3897593
# Submitted batch job 3897594
# Submitted batch job 3897595
# Submitted batch job 3897596
# Submitted batch job 3897597
# Submitted batch job 3897598
# Submitted batch job 3897599
# Submitted batch job 3897600
# Submitted batch job 3897601
# Submitted batch job 3897602
# Submitted batch job 3897603
# Submitted batch job 3897604
# Submitted batch job 3897605
# Submitted batch job 3897606
# Submitted batch job 3897607
# Submitted batch job 3897608
# Submitted batch job 3897609
# Submitted batch job 3897610
# Submitted batch job 3897611
# Submitted batch job 3897612
# Submitted batch job 3897613
# Submitted batch job 3897614
# Submitted batch job 3897615
# Submitted batch job 3897616
# Submitted batch job 3897617
# Submitted batch job 3897618
# Submitted batch job 3897619
# Submitted batch job 3897620
# Submitted batch job 3897621
# Submitted batch job 3897622
# Submitted batch job 3897623
# Submitted batch job 3897624
# Submitted batch job 3897625
# Submitted batch job 3897626
# Submitted batch job 3897627
# Submitted batch job 3897628
# Submitted batch job 3897629
# Submitted batch job 3897630
# Submitted batch job 3897631
# Submitted batch job 3897632
# Submitted batch job 3897633
# Submitted batch job 3897634
# Submitted batch job 3897635
# Submitted batch job 3897636
# Submitted batch job 3897637
# Submitted batch job 3897638
# Submitted batch job 3897639
# Submitted batch job 3897640
# Submitted batch job 3897641
# Submitted batch job 3897642
# Submitted batch job 3897643
# Submitted batch job 3897644
# Submitted batch job 3897645
# Submitted batch job 3897646
# Submitted batch job 3897647
# Submitted batch job 3897648
# Submitted batch job 3897649
# Submitted batch job 3897650
# Submitted batch job 3897651
# Submitted batch job 3897652
# Submitted batch job 3897653
# Submitted batch job 3897654
# Submitted batch job 3897655
# Submitted batch job 3897656
# Submitted batch job 3897657
# Submitted batch job 3897658
# Submitted batch job 3897659
# Submitted batch job 3897660
# Submitted batch job 3897661
# Submitted batch job 3897662
# Submitted batch job 3897663
# Submitted batch job 3897664
# Submitted batch job 3897665
# Submitted batch job 3897666
# Submitted batch job 3897667
# Submitted batch job 3897668
# Submitted batch job 3897669
# Submitted batch job 3897670
# Submitted batch job 3897671
# Submitted batch job 3897672
# Submitted batch job 3897673
# Submitted batch job 3897674
# Submitted batch job 3897675
# Submitted batch job 3897676
# Submitted batch job 3897677
# Submitted batch job 3897678
# Submitted batch job 3897679
# Submitted batch job 3897680
# Submitted batch job 3897681
# Submitted batch job 3897682
# Submitted batch job 3897683
# Submitted batch job 3897684
# Submitted batch job 3897685
# Submitted batch job 3897686
# Submitted batch job 3897687
# Submitted batch job 3897688
# Submitted batch job 3897689
# Submitted batch job 3897690
# Submitted batch job 3897691
# Submitted batch job 3897692
# Submitted batch job 3897693
# Submitted batch job 3897694
# Submitted batch job 3897695
# Submitted batch job 3897696
# Submitted batch job 3897697
# Submitted batch job 3897698
# Submitted batch job 3897699
# Submitted batch job 3897700
# Submitted batch job 3897701
# Submitted batch job 3897702
# Submitted batch job 3897703
# Submitted batch job 3897704
# Submitted batch job 3897705
# Submitted batch job 3897706
# Submitted batch job 3897707
# Submitted batch job 3897708
# Submitted batch job 3897709
# Submitted batch job 3897710
# Submitted batch job 3897711
# Submitted batch job 3897712
# Submitted batch job 3897713
# Submitted batch job 3897714
# Submitted batch job 3897715
# Submitted batch job 3897716
# Submitted batch job 3897717
# Submitted batch job 3897718
# Submitted batch job 3897719
# Submitted batch job 3897720
# Submitted batch job 3897721
# Submitted batch job 3897722
# Submitted batch job 3897723
# Submitted batch job 3897724
# Submitted batch job 3897725
# Submitted batch job 3897726
# Submitted batch job 3897727
# Submitted batch job 3897728
# Submitted batch job 3897729
# Submitted batch job 3897730
# Submitted batch job 3897731
# Submitted batch job 3897732
# Submitted batch job 3897733
# Submitted batch job 3897734
# Submitted batch job 3897735
# Submitted batch job 3897736
# Submitted batch job 3897737
# Submitted batch job 3897738
# Submitted batch job 3897739
# Submitted batch job 3897740
# Submitted batch job 3897741
# Submitted batch job 3897742
# Submitted batch job 3897743
# Submitted batch job 3897744
# Submitted batch job 3897745
# Submitted batch job 3897746
# Submitted batch job 3897747
# Submitted batch job 3897748
# Submitted batch job 3897749
# Submitted batch job 3897750
# Submitted batch job 3897751
# Submitted batch job 3897752
# Submitted batch job 3897753
# Submitted batch job 3897754
# Submitted batch job 3897755
# Submitted batch job 3897756
# Submitted batch job 3897757
# Submitted batch job 3897758
# Submitted batch job 3897759
# Submitted batch job 3897760
# Submitted batch job 3897761
# Submitted batch job 3897762
# Submitted batch job 3897763
# Submitted batch job 3897764
# Submitted batch job 3897765
# Submitted batch job 3897766
# Submitted batch job 3897767
# Submitted batch job 3897768
# Submitted batch job 3897769
# Submitted batch job 3897770
# Submitted batch job 3897771
# Submitted batch job 3897772
# Submitted batch job 3897773
# Submitted batch job 3897774
# Submitted batch job 3897775
# Submitted batch job 3897776
# Submitted batch job 3897777
# Submitted batch job 3897778
# Submitted batch job 3897779
# Submitted batch job 3897780
# Submitted batch job 3897781
# Submitted batch job 3897782
# Submitted batch job 3897783
# Submitted batch job 3897784
# Submitted batch job 3897785
# Submitted batch job 3897786
# Submitted batch job 3897787
# Submitted batch job 3897788
# Submitted batch job 3897789
# Submitted batch job 3897790
# Submitted batch job 3897791
# Submitted batch job 3897792
# Submitted batch job 3897793
# Submitted batch job 3897794
# Submitted batch job 3897795
# Submitted batch job 3897796
# Submitted batch job 3897797
# Submitted batch job 3897798
# Submitted batch job 3897799
# Submitted batch job 3897800
# Submitted batch job 3897801
# Submitted batch job 3897802
# Submitted batch job 3897803
# Submitted batch job 3897804
# Submitted batch job 3897805
# Submitted batch job 3897806
# Submitted batch job 3897807
# Submitted batch job 3897808
# Submitted batch job 3897809
# Submitted batch job 3897810
# Submitted batch job 3897811
# Submitted batch job 3897812
# Submitted batch job 3897813
# Submitted batch job 3897814
# Submitted batch job 3897815
# Submitted batch job 3897816
# Submitted batch job 3897817
# Submitted batch job 3897818
# Submitted batch job 3897819
# Submitted batch job 3897820
# Submitted batch job 3897821
# Submitted batch job 3897822
# Submitted batch job 3897823
# Submitted batch job 3897824
# Submitted batch job 3897825
# Submitted batch job 3897826
# Submitted batch job 3897827
# Submitted batch job 3897828
# Submitted batch job 3897829
# Submitted batch job 3897830
# Submitted batch job 3897831
# Submitted batch job 3897832
# Submitted batch job 3897833
# Submitted batch job 3897834
# Submitted batch job 3897835
# Submitted batch job 3897836
# Submitted batch job 3897837
# Submitted batch job 3897838
# Submitted batch job 3897839
# Submitted batch job 3897840
# Submitted batch job 3897841
# Submitted batch job 3897842
# Submitted batch job 3897843
# Submitted batch job 3897844
# Submitted batch job 3897845
# Submitted batch job 3897846
# Submitted batch job 3897847
# Submitted batch job 3897848
# Submitted batch job 3897849
# Submitted batch job 3897850
# Submitted batch job 3897851
# Submitted batch job 3897852
# Submitted batch job 3897853
# Submitted batch job 3897854
# Submitted batch job 3897855
# Submitted batch job 3897856
# Submitted batch job 3897857
# Submitted batch job 3897858
# Submitted batch job 3897859
# Submitted batch job 3897860
# Submitted batch job 3897861
# Submitted batch job 3897862
# Submitted batch job 3897863
# Submitted batch job 3897864
# Submitted batch job 3897865
# Submitted batch job 3897866
# Submitted batch job 3897867
# Submitted batch job 3897868
# Submitted batch job 3897869
# Submitted batch job 3897870
# Submitted batch job 3897871
# Submitted batch job 3897872
# Submitted batch job 3897873
# Submitted batch job 3897874
# Submitted batch job 3897875
# Submitted batch job 3897876
# Submitted batch job 3897877
# Submitted batch job 3897878
# Submitted batch job 3897879
# Submitted batch job 3897880
# Submitted batch job 3897881
# Submitted batch job 3897882
# Submitted batch job 3897883
# Submitted batch job 3897884
# Submitted batch job 3897885
# Submitted batch job 3897886
# Submitted batch job 3897887
# Submitted batch job 3897888
# Submitted batch job 3897889
# Submitted batch job 3897890
# Submitted batch job 3897891
# Submitted batch job 3897892
# Submitted batch job 3897893
# Submitted batch job 3897894
# Submitted batch job 3897895
# Submitted batch job 3897896
# Submitted batch job 3897897
# Submitted batch job 3897898
# Submitted batch job 3897899
# Submitted batch job 3897900
# Submitted batch job 3897901
# Submitted batch job 3897902
# Submitted batch job 3897903
# Submitted batch job 3897904
# Submitted batch job 3897905
# Submitted batch job 3897906
# Submitted batch job 3897907
# Submitted batch job 3897908
# Submitted batch job 3897909
# Submitted batch job 3897910
# Submitted batch job 3897911
# Submitted batch job 3897912
# Submitted batch job 3897913
# Submitted batch job 3897914
# Submitted batch job 3897915
# Submitted batch job 3897916
# Submitted batch job 3897917
# Submitted batch job 3897918
# Submitted batch job 3897919
# Submitted batch job 3897920
# Submitted batch job 3897921
# Submitted batch job 3897922
# Submitted batch job 3897923
# Submitted batch job 3897924
# Submitted batch job 3897925
# Submitted batch job 3897926
# Submitted batch job 3897927
# Submitted batch job 3897928
# Submitted batch job 3897929
# Submitted batch job 3897930
# Submitted batch job 3897931
# Submitted batch job 3897932
# Submitted batch job 3897933
# Submitted batch job 3897934
# Submitted batch job 3897935
# Submitted batch job 3897936
# Submitted batch job 3897937
# Submitted batch job 3897938
# Submitted batch job 3897939
# Submitted batch job 3897940
# Submitted batch job 3897941
# Submitted batch job 3897942
# Submitted batch job 3897943
# Submitted batch job 3897944
# Submitted batch job 3897945
# Submitted batch job 3897946
# Submitted batch job 3897947
# Submitted batch job 3897948
# Submitted batch job 3897949
# Submitted batch job 3897950
# Submitted batch job 3897951
# Submitted batch job 3897952
# Submitted batch job 3897953
# Submitted batch job 3897954
# Submitted batch job 3897955
# Submitted batch job 3897956
# Submitted batch job 3897957
# Submitted batch job 3897958
# Submitted batch job 3897959
# Submitted batch job 3897960
# Submitted batch job 3897961
# Submitted batch job 3897962
# Submitted batch job 3897963
# Submitted batch job 3897964
# Submitted batch job 3897965
# Submitted batch job 3897966
# Submitted batch job 3897967
# Submitted batch job 3897968
# Submitted batch job 3897969
# Submitted batch job 3897970
# Submitted batch job 3897971
# Submitted batch job 3897972
# Submitted batch job 3897973
# Submitted batch job 3897974
# Submitted batch job 3897975
# Submitted batch job 3897976
# Submitted batch job 3897977
# Submitted batch job 3897978
# Submitted batch job 3897979
# Submitted batch job 3897980
# Submitted batch job 3897981
# Submitted batch job 3897982
# Submitted batch job 3897983
# Submitted batch job 3897984
# Submitted batch job 3897985
# Submitted batch job 3897986
# Submitted batch job 3897987
# Submitted batch job 3897988
# Submitted batch job 3897989
# Submitted batch job 3897990
# Submitted batch job 3897991
# Submitted batch job 3897992
# Submitted batch job 3897993
# Submitted batch job 3897994
# Submitted batch job 3897995
# Submitted batch job 3897996
# Submitted batch job 3897997
# Submitted batch job 3897998
# Submitted batch job 3897999
# Submitted batch job 3898000
# Submitted batch job 3898001
# Submitted batch job 3898002
# Submitted batch job 3898003
# Submitted batch job 3898004
# Submitted batch job 3898005
# Submitted batch job 3898006
# Submitted batch job 3898007
# Submitted batch job 3898008
# Submitted batch job 3898009
# Submitted batch job 3898010
# Submitted batch job 3898011
# Submitted batch job 3898012
# Submitted batch job 3898013
# Submitted batch job 3898014
# Submitted batch job 3898015
# Submitted batch job 3898016
# Submitted batch job 3898017
# Submitted batch job 3898018
# Submitted batch job 3898019
# Submitted batch job 3898020
# Submitted batch job 3898021
# Submitted batch job 3898022
# Submitted batch job 3898023
# Submitted batch job 3898024
# Pipeline Step 5 complete

# %%
n_expected_outputs = len(dt_arr_di_case_d.keys()) + len(dt_arr_di_case_c.keys()) + len(dt_arr_di_case_b.keys())
n_output_fps = len([x for x in dst_p.rglob("*.tif")])

assert(n_expected_outputs == n_output_fps)

# %% [markdown]
# # Pipeline Complete!
