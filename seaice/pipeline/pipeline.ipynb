# %% [markdown]
# # Objective
# The purpose of this notebook is to create a unified dataset of landfast ice extent for the Alaskan coastline from the Mahoney / InteRFACE data collection as described in the exploratory data analysis notebooks and the summary documentation thereof. The notebook is based on the SNAP Data Pipeline concept and template.
#
# ## Pipeline Steps
#
# The flow here is as follows:
#
#     0. Setup - define directories, intial conditions, etc. Execute the setup code cell before any other step
#     1. Fetch the data if it is currently not available locally
#     2. Create a DateTime index that encompasses the entire range of the data and gracefully handle that the atomic units of data here have variable ranges or "durations" on the order of 20 days. Also check that the turnover between calendar years is handled.
#     3. Map the existing data collection to this index.
#     4. For each item in the existing data collection constrain the valid array values and establish a common and well known spatial reference.
#     5. Create a merged raster from Chukchi and Beaufort data (or lackthereof) for each date in the time index with appropriate data types and NoData values.
#
# Creating the ultimate GeoTIFFs (step 5) will require understanding the four possibles cases of data availability for each date in our DateTime Index.
#
#     A: No data is available at all.
#     B: A single raster exists from only one region.
#     C: Multiple rasters exist from only one region.
#     D: One or more rasters exist from both regions.
#
# We can handle these cases like so:
#
#  - Case A: Skip these dates for now, there is no data available. These dates can be brought back into a datacube at a later time if needed.
#
#  - Case B: Take the single raster and merge it with the mask for whichever region has no data.
#
#  - Case C: Take all the rasters and create a 3D array of values, and filter for the maximum of the time index. Then merge these data with the mask for whichever region has no data.
#
#  - Case D. Same as above, but do the stacking and filtering for both regions, and then then merge those two outputs together.

# %% [markdown]
# ## 0 - Setup
#
# The following environment variables should be set before running this notebook:
# - `$SRC_DIR`: the base directory for storing project data that should be backed up.
# - `$DST_DIR`: the output directory where final products are placed.
# - `$SCRATCH_DIR`: scratch directory for storing project data which does not need to be backed up.
#
# I like to set these variables from within the notebook for clarity, but it could be done from your shell also.

# %%
# place all imports here
import config # this sets the GDAL and PROJ envs before importing geospatial libs
import os
import shutil
import re
import datetime
import pandas as pd
import rasterio as rio
import numpy as np
import pickle
import slurm
from pathlib import Path
from rasterio.crs import CRS
from rasterio.merge import merge
# local helper library, like clippy
import helpers as snappy
# constants
NCORES = 32
SLURM_MAIL = "cparr4@alaska.edu"
AC_CONDA_ENV = "/home/UA/cparr4/miniconda3/envs/conda-project"
COPY_SOURCE = False
project_dir = os.getcwd()


# set the environment variables and create directories and Path objects
os.environ["BASE_DIR"] = "/workspace/Data/Base_Data/Cryosphere/landfast_seaice"
src_p = Path(os.environ["BASE_DIR"])

os.environ["DST_DIR"] = "/atlas_scratch/cparr4/landfast_seaice/mahoney_preprocess/outputs"
dst_p = Path(os.environ["DST_DIR"]).mkdir(parents=True, exist_ok=True)
dst_p = Path(os.environ["DST_DIR"])

os.environ["SCRATCH_DIR"] = "/atlas_scratch/cparr4/landfast_seaice/mahoney_preprocess/scratch"
scratch_p = Path(os.environ["SCRATCH_DIR"]).mkdir(parents=True, exist_ok=True)
scratch_p = Path(os.environ["SCRATCH_DIR"])

# create scratch directory copied and renamed source GeoTIFFs
copy_dir = scratch_p.joinpath("src_copy")
copy_dir.mkdir(exist_ok=True, parents=True)

# create scratch directory for slurm scripts
slurm_dir = scratch_p.joinpath("slurm")
slurm_dir.mkdir(exist_ok=True, parents=True)

# create scratch directory for GeoTIFFs with corrected array values
arrfix_dir = scratch_p.joinpath("arrfix")
arrfix_dir.mkdir(exist_ok=True, parents=True)

# create scratch directory for regional mask or "dummy" GeoTIFFs
mask_dir = scratch_p.joinpath("mask")
mask_dir.mkdir(exist_ok=True, parents=True)

# create scratch directory for max-filtered GeoTIFFs to handle Cases C and D
max_dir = scratch_p.joinpath("max")
max_dir.mkdir(exist_ok=True, parents=True)

snappy.t_out = open("/dev/stdout", "w")
snappy.jprint("Executing pipeline Step 0 (setup)\n")
snappy.jprint(f"SRC_DIR set to {src_p}")
snappy.jprint(f"DST_DIR set to {dst_p}")
snappy.jprint(f"SCRATCH_DIR set to {scratch_p}\n")
snappy.jprint("Pipeline Step 0 (setup) complete\n")
snappy.jprint("Current snapshot of the working directories:")
_ = os.system("cd $SCRATCH_DIR/.. && tree -d")
# Out:
# Executing pipeline Step 0 (setup)
#
# SRC_DIR set to /workspace/Data/Base_Data/Cryosphere/landfast_seaice
# DST_DIR set to /atlas_scratch/cparr4/landfast_seaice/mahoney_preprocess/outputs
# SCRATCH_DIR set to /atlas_scratch/cparr4/landfast_seaice/mahoney_preprocess/scratch
#
# Pipeline Step 0 (setup) complete
#
# Current snapshot of the working directories:
# .
# ├── outputs
# └── scratch
#     ├── arrfix
#     ├── mask
#     ├── max
#     ├── slurm
#     └── src_copy
#
# 7 directories

# %% [markdown]
# ## 1 - Fetch
#
# We don't have to download any data - these are on our file system. We'll use the fetch stage to point at the data and create the list of filenames we'll use. We can also copy the source data to our scratch directory and do a file name clean up.

# %%
snappy.jprint("Executing pipeline Step 1 (fetch)\n")

slie_fps = [x for x in src_p.rglob("*_slie.tif")]
n_src_fps = len(slie_fps)
new_fps = [copy_dir / ''.join(x.parent.parent.name.lower() + "_" + x.name) for x in slie_fps]

if COPY_SOURCE:
    for src, dst in zip(slie_fps, new_fps):
        shutil.copy(src, dst)

snappy.jprint(f"Source data consists of {n_src_fps} Geotiffs, for example:")
snappy.jprint(slie_fps[0])

n_copied_fps = len([x for x in copy_dir.rglob("*_slie.tif")])

assert(n_src_fps == n_copied_fps)

snappy.jprint("Pipeline Step 1 complete\n")
# Out:
# Executing pipeline Step 1 (fetch)
#
# Source data consists of 566 Geotiffs, for example:
# /workspace/Data/Base_Data/Cryosphere/landfast_seaice/Beaufort/2000-01/r2000_286-311_slie.tif
# Pipeline Step 1 complete

# %% [markdown]
# ## 2 - Create Time Index
#
# We'll write a few functions to parse file names and convert day-of-year (DOY) style dates to a more readable and DateTime friendly YYYY-MM-DD format. The file names are of the style `chukchi_r2007_326-350_slie.tif`. We'll construct a lookup where we can see all the date information associated with each file. We need to be aware that negative durations are lurking where we jump to the next calendar year.
#
# Once those durations are fixed and all the date information is in place we can establish the start and end dates of the entire collection and create a DateTime index that encompasses all the data.

# %%
snappy.jprint("Executing pipeline Step 2 (time index)\n")

def create_regional_fp(fp):
    """Construct a new filename that contains the region info."""
    new_fp = dst_p / ''.join(fp.parent.parent.name.lower() + "_" + fp.name)
    return new_fp
    

def get_doy(fp):
    """Fetch the DOY range from a file name."""
    try:
        doy = re.match(r'.*([0-3][0-9][0-9]-[0-3][0-9][0-9])', fp).group(1)
    except:
        doy = re.match(r'.*([0-3][0-9][0-9]_[0-3][0-9][0-9])', fp).group(1)
        doy = doy.replace("_", "-")
    return doy


def get_re_year(fp):
    """Fetch a single year (YYYY) from a file name."""
    year = re.match(r'.*([1-3][0-9]{3})', fp).group(1)
    return int(year)


def split_doy(doy_range):
    """Split a DOY range string into a integer start and end."""
    doy_start, doy_end = doy_range.split("-")
    return int(doy_start), int(doy_end)    


def doy_date_to_YYYYMMDD(year, days):
    """Convert a a DOY + Year date to a YYYY-MM-DD datetime object."""
    dt = datetime.datetime(year, 1, 1) + datetime.timedelta(days - 1)
    return dt


di = {}
for fp in slie_fps:
    
    k = create_regional_fp(fp).name
    di[k] = {}
    di[k]["start_year"] = get_re_year(k)
    di[k]["doy_range"] = get_doy(k)
    di[k]["doy_start"], di[k]["doy_end"] = split_doy(di[k]["doy_range"])
    di[k]["dt_start"] = doy_date_to_YYYYMMDD(di[k]["start_year"], di[k]["doy_start"])
    di[k]["dt_end"] = doy_date_to_YYYYMMDD(di[k]["start_year"], di[k]["doy_end"])
    di[k]["dt_duration"] = di[k]["dt_end"] - di[k]["dt_start"]

snappy.jprint("Example of a lookup with an incorrect duration:\n")
snappy.jprint(di['beaufort_r2000_349-003_slie.tif'])

def set_end_year(di):
    """Adds an end year for each file and handles rollover cases."""
    for k in di.keys():
        if di[k]["dt_duration"].days < 0:
            di[k]["end_year"] = di[k]["start_year"] + 1
            di[k]["dt_end"] = doy_date_to_YYYYMMDD(di[k]["end_year"], di[k]["doy_end"])
            di[k]["dt_duration"] = di[k]["dt_end"] - di[k]["dt_start"]

        else:
            di[k]["end_year"] = di[k]["start_year"]


set_end_year(di)
snappy.jprint("\n")
snappy.jprint("Example of a lookup with a corrected duration:\n")
snappy.jprint(di['beaufort_r2000_349-003_slie.tif'])


def get_first_dt(di):
    """Get the earliest chronological start date from the lookup."""
    start_dts = []
    for k in di.keys():
        start_dts.append(di[k]["dt_start"])
    start_dt = sorted(start_dts)[0]
    return start_dt


def get_last_dt(di):
    """Get the latest chronological end date from the lookup."""
    end_dts = []
    for k in di.keys():
        end_dts.append(di[k]["dt_end"])
    last_dt = sorted(end_dts)[-1]
    return last_dt

end = get_last_dt(di)
start = get_first_dt(di)
dt_range = pd.date_range(start=start, end=end)
snappy.jprint(f"\nEarliest chronological date is {start}\n")
snappy.jprint(f"Latest chronological date is {end}\n")
snappy.jprint("Pipeline Step 2 complete\n")
# Out:
# Executing pipeline Step 2 (time index)
#
# Example of a lookup with an incorrect duration:
#
# {'start_year': 2000, 'doy_range': '349-003', 'doy_start': 349, 'doy_end': 3, 'dt_start': datetime.datetime(2000, 12, 14, 0, 0), 'dt_end': datetime.datetime(2000, 1, 3, 0, 0), 'dt_duration': datetime.timedelta(days=-346)}
#
#
# Example of a lookup with a corrected duration:
#
# {'start_year': 2000, 'doy_range': '349-003', 'doy_start': 349, 'doy_end': 3, 'dt_start': datetime.datetime(2000, 12, 14, 0, 0), 'dt_end': datetime.datetime(2001, 1, 3, 0, 0), 'dt_duration': datetime.timedelta(days=20), 'end_year': 2001}
#
# Earliest chronological date is 1996-10-17 00:00:00
#
# Latest chronological date is 2008-07-14 00:00:00
#
# Pipeline Step 2 complete

# %% [markdown]
# ## 3 - Map Existing Data to the Time Index
#
# Because each file spans many days, a single calendar day can be represented by more than one raster. We need to map dates to the representative rasters by checking if the date is in the time range represented by the file. We'll want to know how many files match from the Beaufort region, how many from the Chukchi region, and how many match total. We also expect that some calendar days will have no matches at all (e.g., August, which is not in the seasonal ice cycle). We'll create a new lookup keyed by each date in the DateTime Index that stores the above information and the matching file names.
#
# Some individual days are represented by as many as six rasters across both regions! We'll stash some pickle files to indicate which dates correspond to which cases described in the introduction.

# %%
def time_in_range(start, end, x):
    """Return true if x is in the range [start, end]"""
    if start <= end:
        return start <= x <= end
    else:
        return start <= x or x <= end

dt_di = {}

for dt in dt_range:
    dt_di[dt] = {}
    dt_di[dt]["matching data"] = []
    beaufort_count = 0
    chukchi_count = 0
    
    for k in di.keys():
        if time_in_range(di[k]["dt_start"], di[k]["dt_end"], dt):
            dt_di[dt]["matching data"].append(k)
            
            if "beaufort" in k.lower():
                beaufort_count += 1
            if "chukchi" in k.lower():
                chukchi_count += 1
            
    if len(dt_di[dt]["matching data"]) == 0:
        dt_di[dt]["matching data"].append("no data")
    
    dt_di[dt]["beaufort_count"] = beaufort_count
    dt_di[dt]["chukchi_count"] = chukchi_count
    dt_di[dt]["match_count"] = chukchi_count + beaufort_count
    
df = pd.DataFrame.from_dict(dt_di).T

snappy.jprint("\nSample of mapping data to a time stamp:\n")
snappy.jprint(df.sort_values("match_count", ascending=False).iloc[1])

conditions = [
    (df["match_count"] == 0),
    (df["match_count"] == 1),
    ((df["match_count"] > 1) & (df["chukchi_count"] * df["beaufort_count"] == 0)),
    ((df["match_count"] > 1) & (df["chukchi_count"] * df["beaufort_count"] != 0))]
choices = [1, 2, 3, 4] # these map to A, B, C, and D
df["merge_case"] = np.select(conditions, choices)

snappy.jprint("\nSummary of merge cases - most have data from both regions which is good.\n")
snappy.jprint(df["merge_case"].value_counts())
snappy.jprint("Writing pickles of each merge case to use in processing functions called by slurm.")

merge_case_b = df[df.merge_case == 2]
dt_arr_di_case_b = merge_case_b.T.to_dict()
with open(max_dir / "single_raster_single_region.pickle", "wb") as handle:
    pickle.dump(dt_arr_di_case_b, handle, protocol=pickle.HIGHEST_PROTOCOL)

merge_case_c = df[df.merge_case == 3]
dt_arr_di_case_c = merge_case_c.T.to_dict()
with open(max_dir / "many_raster_single_region.pickle", "wb") as handle:
    pickle.dump(dt_arr_di_case_c, handle, protocol=pickle.HIGHEST_PROTOCOL)

merge_case_d = df[df.merge_case == 4]
dt_arr_di_case_d = merge_case_d.T.to_dict()
with open(max_dir / "many_raster_both_regions.pickle", "wb") as handle:
    pickle.dump(dt_arr_di_case_d, handle, protocol=pickle.HIGHEST_PROTOCOL)

snappy.jprint("\nPipeline Step 3 complete\n")
# Out:
# Sample of mapping data to a time stamp:
#
# matching data     [beaufort_r2006_058-084_slie.tif, beaufort_r20...
# beaufort_count                                                    3
# chukchi_count                                                     3
# match_count                                                       6
# Name: 2006-03-23 00:00:00, dtype: object
#
# Summary of merge cases - most have data from both regions which is good.
#
# 4    2510
# 3     829
# 1     797
# 2     153
# Name: merge_case, dtype: int64
# Writing pickles of each merge case to use in processing functions called by slurm.
#
# Pipeline Step 3 complete

# %% [markdown]
# ## 4 - Constrain and Fix the Array Values, Spatial References, and Generate Masks
#
# The next step is to constrain our array values to a known range. We know from our EDA work the value schema in the existing collection is as follows:
#
#  - 0: No landfast sea ice is present for this pixel. This means either water, or sea-ice that is NOT landfast.
#  - 255: landfast sea ice is present for this pixel
#  - 128: A landmask.
#  - 63, 64, other oddball values: NoData
#
# These values can be reduced to binary set where `0` indicates the absence of landfast sea ice and `1` the presence of it.
#
# We'll define a function (see `fix_raster_values.py`) that forces this array value mapping and writes a new GeoTIFF.
#
# Also, at this stage we can also create cohesive spatial references and raster creation profiles. Ultimately we want to create a merged raster as well, so we'll create three new rasters and raster profiles:
# 1. An empty mask (all zeros) for the Chukchi Region
# 2. An empty mask (all zeros) for the Beaufort Region
# 3. An empty mask (all zeros) for the combined Chukchi and Beaufort regions
#
# Once we have established cohesive raster profiles, we can generate the function arguments that will be used to consolidate the array values. The fixed output GeoTIFFs will just have an "arrfix" prefix and be stashed in the `scratch/arrfix` directory.

# %%
snappy.jprint("Executing pipeline Step 4 (fix the array values and spatial references and generate masks)\n")

# create cohesive raster profiles
beauf_sample = new_fps[0]
chuk_sample = new_fps[-1]

with rio.open(beauf_sample) as beauf_src:
    beauf_src = rio.open(beauf_sample)
    beauf_profile = beauf_src.profile
beauf_profile["crs"] = CRS.from_epsg(3338)
beauf_profile.update(compress="lzw")

with rio.open(chuk_sample):
    chuk_src = rio.open(chuk_sample)
    chuk_profile = chuk_src.profile
chuk_profile["crs"] = CRS.from_epsg(3338)
chuk_profile.update(compress="lzw")

arr_merge, aff_merge = merge([beauf_src, chuk_src])

new_profile = chuk_profile.copy()
new_profile["height"], new_profile["width"] = arr_merge[0].shape
new_profile["transform"] = aff_merge
new_profile["crs"] = CRS.from_epsg(3338)
new_profile.update(compress="lzw")

with open(mask_dir / "beaufort_raster_profile.pickle", "wb") as handle:
    pickle.dump(beauf_profile, handle, protocol=pickle.HIGHEST_PROTOCOL)
with open(mask_dir / "chukchi_raster_profile.pickle", "wb") as handle:
    pickle.dump(chuk_profile, handle, protocol=pickle.HIGHEST_PROTOCOL)
with open(mask_dir / "both_region_profile.pickle", "wb") as handle:
    pickle.dump(new_profile, handle, protocol=pickle.HIGHEST_PROTOCOL)

# generate the masks and write to disk
with rio.open(mask_dir / "both_region_mask.tif", 'w', **new_profile) as dst:
        dst.write(np.zeros(arr_merge[0].shape), 1)

with rio.open(mask_dir / "beaufort_mask.tif", 'w', **beauf_profile) as dst:
        dst.write(np.zeros((beauf_profile["height"], beauf_profile["width"])), 1)

with rio.open(mask_dir / "chukchi_mask.tif", 'w', **chuk_profile) as dst:
        dst.write(np.zeros((chuk_profile["height"], chuk_profile["width"])), 1)
        
# we want the mask paths for later
both_mask_fp = mask_dir / "both_region_mask.tif"
chuk_mask_fp = mask_dir / "chukchi_mask.tif"
beauf_mask_fp = mask_dir / "beaufort_mask.tif"

# nice to indicate when data are written to disk
mask_fps = list(mask_dir.glob('*'))
snappy.jprint(f"{len(mask_fps)} files written to {mask_dir}")

snappy.jprint("\nGenerating Slurm scripts to correct the raster values and write new GeoTIFFs.")

# write slurm scripts to fix the raster values of an individual file
project_dir = os.getcwd()

chuk_fps = list(copy_dir.glob("chukchi*"))
chuk_pkl = mask_dir / "chukchi_raster_profile.pickle" 
beauf_fps = list(copy_dir.glob("beaufort*"))
beauf_pkl = mask_dir / "beaufort_raster_profile.pickle" 


chuk_slurm_fps = [
    slurm.write_sbatch(
        NCORES, SLURM_MAIL, slurm_dir, AC_CONDA_ENV, fp, chuk_pkl, project_dir, arrfix_dir
    ) 
    for fp in chuk_fps
]

snappy.jprint(f"\n{len(chuk_slurm_fps)} slurm scripts for the Chukchi written to {slurm_dir}")
snappy.jprint("\nExecuting Chukchi slurm scripts with sbatch...")

# Call the slurm scripts with the `sbatch` command
_ = [os.system(f"sbatch {fp}") for fp in chuk_slurm_fps]

snappy.jprint(f"\n{len(chuk_slurm_fps)} slurm scripts for the Beaufort written to {slurm_dir}")
snappy.jprint("\nExecuting Beaufort slurm scripts with sbatch...\n")
beaufort_slurm_fps = [
    slurm.write_sbatch(
        NCORES, SLURM_MAIL, slurm_dir, AC_CONDA_ENV, fp, beauf_pkl, project_dir, arrfix_dir
    ) 
    for fp in beauf_fps
]

_ = [os.system(f"sbatch {fp}") for fp in beaufort_slurm_fps]

snappy.jprint("Pipeline Step 4 complete\n")
# Out:
# Executing pipeline Step 4 (fix the array values and spatial references and generate masks)
#
# 6 files written to /atlas_scratch/cparr4/landfast_seaice/mahoney_preprocess/scratch/mask
#
# Generating Slurm scripts to correct the raster values and write new GeoTIFFs.
#
# 316 slurm scripts for the Chukchi written to /atlas_scratch/cparr4/landfast_seaice/mahoney_preprocess/scratch/slurm
#
# Executing Chukchi slurm scripts with sbatch...
#
# 316 slurm scripts for the Beaufort written to /atlas_scratch/cparr4/landfast_seaice/mahoney_preprocess/scratch/slurm
#
# Executing Beaufort slurm scripts with sbatch...
#
# Submitted batch job 3885672
# Submitted batch job 3885673
# Submitted batch job 3885674
# Submitted batch job 3885675
# Submitted batch job 3885676
# Submitted batch job 3885677
# Submitted batch job 3885678
# Submitted batch job 3885679
# Submitted batch job 3885680
# Submitted batch job 3885681
# Submitted batch job 3885682
# Submitted batch job 3885683
# Submitted batch job 3885684
# Submitted batch job 3885685
# Submitted batch job 3885686
# Submitted batch job 3885687
# Submitted batch job 3885688
# Submitted batch job 3885689
# Submitted batch job 3885690
# Submitted batch job 3885691
# Submitted batch job 3885810
# Submitted batch job 3885811
# Submitted batch job 3885812
# Submitted batch job 3885813
# Submitted batch job 3885814
# Submitted batch job 3885815
# Submitted batch job 3885816
# Submitted batch job 3885817
# Submitted batch job 3885818
# Submitted batch job 3885819
# Submitted batch job 3885820
# Submitted batch job 3885821
# Submitted batch job 3885822
# Submitted batch job 3885823
# Submitted batch job 3885824
# Submitted batch job 3885825
# Submitted batch job 3885826
# Submitted batch job 3885827
# Submitted batch job 3885828
# Submitted batch job 3885829
# Submitted batch job 3885830
# Submitted batch job 3885831
# Submitted batch job 3885832
# Submitted batch job 3885833
# Submitted batch job 3885834
# Submitted batch job 3885835
# Submitted batch job 3885836
# Submitted batch job 3885837
# Submitted batch job 3885838
# Submitted batch job 3885839
# Submitted batch job 3885840
# Submitted batch job 3885841
# Submitted batch job 3885842
# Submitted batch job 3885843
# Submitted batch job 3885844
# Submitted batch job 3885845
# Submitted batch job 3885846
# Submitted batch job 3885847
# Submitted batch job 3885848
# Submitted batch job 3885849
# Submitted batch job 3885850
# Submitted batch job 3885851
# Submitted batch job 3885852
# Submitted batch job 3885853
# Submitted batch job 3885854
# Submitted batch job 3885855
# Submitted batch job 3885856
# Submitted batch job 3885857
# Submitted batch job 3885858
# Submitted batch job 3885859
# Submitted batch job 3885860
# Submitted batch job 3885861
# Submitted batch job 3885862
# Submitted batch job 3885863
# Submitted batch job 3885864
# Submitted batch job 3885865
# Submitted batch job 3885866
# Submitted batch job 3885867
# Submitted batch job 3885868
# Submitted batch job 3885869
# Submitted batch job 3885870
# Submitted batch job 3885871
# Submitted batch job 3885872
# Submitted batch job 3885873
# Submitted batch job 3885874
# Submitted batch job 3885875
# Submitted batch job 3885876
# Submitted batch job 3885877
# Submitted batch job 3885878
# Submitted batch job 3885879
# Submitted batch job 3885880
# Submitted batch job 3885881
# Submitted batch job 3885882
# Submitted batch job 3885883
# Submitted batch job 3885884
# Submitted batch job 3885885
# Submitted batch job 3885886
# Submitted batch job 3885887
# Submitted batch job 3885888
# Submitted batch job 3885889
# Submitted batch job 3885890
# Submitted batch job 3885891
# Submitted batch job 3885892
# Submitted batch job 3885893
# Submitted batch job 3885894
# Submitted batch job 3885895
# Submitted batch job 3885896
# Submitted batch job 3885897
# Submitted batch job 3885898
# Submitted batch job 3885899
# Submitted batch job 3885900
# Submitted batch job 3885901
# Submitted batch job 3885902
# Submitted batch job 3885903
# Submitted batch job 3885904
# Submitted batch job 3885905
# Submitted batch job 3885906
# Submitted batch job 3885907
# Submitted batch job 3885908
# Submitted batch job 3885909
# Submitted batch job 3885910
# Submitted batch job 3885911
# Submitted batch job 3885912
# Submitted batch job 3885913
# Submitted batch job 3885914
# Submitted batch job 3885915
# Submitted batch job 3885916
# Submitted batch job 3885917
# Submitted batch job 3885918
# Submitted batch job 3885919
# Submitted batch job 3885920
# Submitted batch job 3885921
# Pipeline Step 4 complete

# %%
n_fixed_fps = len([x for x in arrfix_dir.rglob("*.tif")])
assert(n_copied_fps == n_fixed_fps)

# %% [markdown]
# ## 5 - Create rasters that represent all possible data for a given date.
#
# This where we handle cases B, C, and D that we described earlier. The code that executes the logic of these cases (also described earlier) lives in the Python scripts that are slurmed.

# %%
snappy.jprint("Executing pipeline Step 5 (Create merged rasters)\n")

case_b_pkl = Path(max_dir / "single_raster_single_region.pickle")
case_b_slurm_dts = [
    slurm.write_case_b(
        NCORES, SLURM_MAIL, slurm_dir, AC_CONDA_ENV, case_b_pkl, k, project_dir, mask_dir, arrfix_dir, dst_p
    ) 
    for k in dt_arr_di_case_b.keys()
]
_ = [os.system(f"sbatch {x}") for x in case_b_slurm_dts]

case_c_pkl = Path(max_dir / "many_raster_single_region.pickle")
case_c_slurm_dts = [
    slurm.write_case_c(
        NCORES, SLURM_MAIL, slurm_dir, AC_CONDA_ENV, case_c_pkl, k, project_dir, mask_dir, max_dir, arrfix_dir, dst_p
    ) 
    for k in dt_arr_di_case_c.keys()
]
_ = [os.system(f"sbatch {x}") for x in case_c_slurm_dts]

case_d_pkl = Path(max_dir / "many_raster_both_regions.pickle")
case_d_slurm_dts = [
    slurm.write_case_d(
        NCORES, SLURM_MAIL, slurm_dir, AC_CONDA_ENV, case_d_pkl, k, project_dir, mask_dir, max_dir, arrfix_dir, dst_p
    ) 
    for k in dt_arr_di_case_d.keys()
]
_ = [os.system(f"sbatch {x}") for x in case_d_slurm_dts]

snappy.jprint("Pipeline Step 5 complete\n")
# Out:
# Executing pipeline Step 5 (Create merged rasters)
#
# Submitted batch job 3882180
# Submitted batch job 3882181
# Submitted batch job 3882182
# Submitted batch job 3882183
# Submitted batch job 3882184
# Submitted batch job 3882185
# Submitted batch job 3882186
# Submitted batch job 3882187
# Submitted batch job 3882188
# Submitted batch job 3882189
# Submitted batch job 3882190
# Submitted batch job 3882191
# Submitted batch job 3882192
# Submitted batch job 3882193
# Submitted batch job 3882194
# Submitted batch job 3882195
# Submitted batch job 3882196
# Submitted batch job 3882197
# Submitted batch job 3882198
# Submitted batch job 3882199
# Submitted batch job 3882200
# Submitted batch job 3882201
# Submitted batch job 3882202
# Submitted batch job 3882203
# Submitted batch job 3882204
# Submitted batch job 3882205
# Submitted batch job 3882206
# Submitted batch job 3882207
# Submitted batch job 3882208
# Submitted batch job 3882209
# Submitted batch job 3882210
# Submitted batch job 3882211
# Submitted batch job 3882212
# Submitted batch job 3882213
# Submitted batch job 3882214
# Submitted batch job 3882215
# Submitted batch job 3882216
# Submitted batch job 3882217
# Submitted batch job 3882218
# Submitted batch job 3882219
# Submitted batch job 3882220
# Submitted batch job 3882221
# Submitted batch job 3882222
# Submitted batch job 3882223
# Submitted batch job 3882224
# Submitted batch job 3882225
# Submitted batch job 3882226
# Submitted batch job 3882227
# Submitted batch job 3882228
# Submitted batch job 3882229
# Submitted batch job 3882230
# Submitted batch job 3882231
# Submitted batch job 3882232
# Submitted batch job 3882233
# Submitted batch job 3882234
# Submitted batch job 3882235
# Submitted batch job 3882236
# Submitted batch job 3882237
# Submitted batch job 3882238
# Submitted batch job 3882239
# Submitted batch job 3882945
# Submitted batch job 3882946
# Submitted batch job 3882947
# Submitted batch job 3882948
# Submitted batch job 3882949
# Submitted batch job 3882950
# Submitted batch job 3882951
# Submitted batch job 3882952
# Submitted batch job 3882953
# Submitted batch job 3882954
# Submitted batch job 3882955
# Submitted batch job 3882956
# Submitted batch job 3882957
# Submitted batch job 3882958
# Submitted batch job 3882959
# Submitted batch job 3882960
# Submitted batch job 3882961
# Submitted batch job 3882962
# Submitted batch job 3882963
# Submitted batch job 3882964
# Submitted batch job 3882965
# Submitted batch job 3882966
# Submitted batch job 3882967
# Submitted batch job 3882968
# Submitted batch job 3882969
# Submitted batch job 3882970
# Submitted batch job 3882971
# Submitted batch job 3882972
# Submitted batch job 3882973
# Submitted batch job 3882974
# Submitted batch job 3882975
# Submitted batch job 3882976
# Submitted batch job 3882977
# Submitted batch job 3882978
# Submitted batch job 3882979
# Submitted batch job 3882980
# Submitted batch job 3882981
# Submitted batch job 3882982
# Submitted batch job 3882983
# Submitted batch job 3882984
# Submitted batch job 3882985
# Submitted batch job 3882986
# Submitted batch job 3882987
# Submitted batch job 3882988
# Submitted batch job 3882989
# Submitted batch job 3882990
# Submitted batch job 3882991
# Submitted batch job 3882992
# Submitted batch job 3882993
# Submitted batch job 3882994
# Submitted batch job 3882995
# Submitted batch job 3882996
# Submitted batch job 3882997
# Submitted batch job 3882998
# Submitted batch job 3882999
# Submitted batch job 3883000
# Submitted batch job 3883001
# Submitted batch job 3883002
# Submitted batch job 3883003
# Submitted batch job 3883004
# Submitted batch job 3883005
# Submitted batch job 3883006
# Submitted batch job 3883007
# Submitted batch job 3883008
# Submitted batch job 3883009
# Submitted batch job 3883010
# Submitted batch job 3883011
# Submitted batch job 3883012
# Submitted batch job 3883013
# Submitted batch job 3883014
# Submitted batch job 3883015
# Submitted batch job 3883016
# Submitted batch job 3883017
# Submitted batch job 3883018
# Submitted batch job 3883019
# Submitted batch job 3883020
# Submitted batch job 3883021
# Submitted batch job 3883022
# Submitted batch job 3883023
# Submitted batch job 3883024
# Submitted batch job 3883025
# Submitted batch job 3883026
# Submitted batch job 3883027
# Submitted batch job 3883028
# Submitted batch job 3883029
# Submitted batch job 3883030
# Submitted batch job 3883031
# Submitted batch job 3883032
# Submitted batch job 3883033
# Submitted batch job 3883034
# Submitted batch job 3883035
# Submitted batch job 3883036
# Submitted batch job 3883037
# Submitted batch job 3883038
# Submitted batch job 3883039
# Submitted batch job 3883040
# Submitted batch job 3883041
# Submitted batch job 3883042
# Submitted batch job 3883043
# Submitted batch job 3883044
# Submitted batch job 3883045
# Submitted batch job 3883046
# Submitted batch job 3883047
# Submitted batch job 3883048
# Submitted batch job 3883049
# Submitted batch job 3883050
# Submitted batch job 3883051
# Submitted batch job 3883052
# Submitted batch job 3883053
# Submitted batch job 3883054
# Submitted batch job 3883055
# Submitted batch job 3883056
# Submitted batch job 3883057
# Submitted batch job 3883058
# Submitted batch job 3883059
# Submitted batch job 3883060
# Submitted batch job 3883061
# Submitted batch job 3883062
# Submitted batch job 3883063
# Submitted batch job 3883064
# Submitted batch job 3883065
# Submitted batch job 3883066
# Submitted batch job 3883067
# Submitted batch job 3883068
# Submitted batch job 3883069
# Submitted batch job 3883070
# Submitted batch job 3883071
# Submitted batch job 3883072
# Submitted batch job 3883073
# Submitted batch job 3883074
# Submitted batch job 3883075
# Submitted batch job 3883076
# Submitted batch job 3883077
# Submitted batch job 3883078
# Submitted batch job 3883079
# Submitted batch job 3883080
# Submitted batch job 3883081
# Submitted batch job 3883082
# Submitted batch job 3883083
# Submitted batch job 3883084
# Submitted batch job 3883085
# Submitted batch job 3883086
# Submitted batch job 3883087
# Submitted batch job 3883088
# Submitted batch job 3883089
# Submitted batch job 3883090
# Submitted batch job 3883091
# Submitted batch job 3883092
# Submitted batch job 3883093
# Submitted batch job 3883094
# Submitted batch job 3883095
# Submitted batch job 3883096
# Submitted batch job 3883097
# Submitted batch job 3883098
# Submitted batch job 3883099
# Submitted batch job 3883100
# Submitted batch job 3883101
# Submitted batch job 3883102
# Submitted batch job 3883103
# Submitted batch job 3883104
# Submitted batch job 3883105
# Submitted batch job 3883106
# Submitted batch job 3883107
# Submitted batch job 3883108
# Submitted batch job 3883109
# Submitted batch job 3883110
# Submitted batch job 3883111
# Submitted batch job 3883112
# Submitted batch job 3883113
# Submitted batch job 3883114
# Submitted batch job 3883115
# Submitted batch job 3883116
# Submitted batch job 3883117
# Submitted batch job 3883118
# Submitted batch job 3883119
# Submitted batch job 3883120
# Submitted batch job 3883121
# Submitted batch job 3883122
# Submitted batch job 3883123
# Submitted batch job 3883124
# Submitted batch job 3883125
# Submitted batch job 3883126
# Submitted batch job 3883127
# Submitted batch job 3883128
# Submitted batch job 3883129
# Submitted batch job 3883130
# Submitted batch job 3883131
# Submitted batch job 3883132
# Submitted batch job 3883133
# Submitted batch job 3883134
# Submitted batch job 3883135
# Submitted batch job 3883136
# Submitted batch job 3883137
# Submitted batch job 3883138
# Submitted batch job 3883139
# Submitted batch job 3883140
# Submitted batch job 3883141
# Submitted batch job 3883142
# Submitted batch job 3883143
# Submitted batch job 3883144
# Submitted batch job 3883145
# Submitted batch job 3883146
# Submitted batch job 3883147
# Submitted batch job 3883148
# Submitted batch job 3883149
# Submitted batch job 3883150
# Submitted batch job 3883151
# Submitted batch job 3883152
# Submitted batch job 3883153
# Submitted batch job 3883154
# Submitted batch job 3883155
# Submitted batch job 3883156
# Submitted batch job 3883157
# Submitted batch job 3883158
# Submitted batch job 3883159
# Submitted batch job 3883160
# Submitted batch job 3883161
# Submitted batch job 3883162
# Submitted batch job 3883163
# Submitted batch job 3883164
# Submitted batch job 3883165
# Submitted batch job 3883166
# Submitted batch job 3883167
# Submitted batch job 3883168
# Submitted batch job 3883169
# Submitted batch job 3883170
# Submitted batch job 3883171
# Submitted batch job 3883172
# Submitted batch job 3883173
# Submitted batch job 3883174
# Submitted batch job 3883175
# Submitted batch job 3883176
# Submitted batch job 3883177
# Submitted batch job 3883178
# Submitted batch job 3883179
# Submitted batch job 3883180
# Submitted batch job 3883181
# Submitted batch job 3883182
# Submitted batch job 3883183
# Submitted batch job 3883184
# Submitted batch job 3883185
# Submitted batch job 3883186
# Submitted batch job 3883187
# Submitted batch job 3883188
# Submitted batch job 3883189
# Submitted batch job 3883190
# Submitted batch job 3883191
# Submitted batch job 3883192
# Submitted batch job 3883193
# Submitted batch job 3883194
# Submitted batch job 3883195
# Submitted batch job 3883196
# Submitted batch job 3883197
# Submitted batch job 3883198
# Submitted batch job 3883199
# Submitted batch job 3883200
# Submitted batch job 3883201
# Submitted batch job 3883202
# Submitted batch job 3883203
# Submitted batch job 3883204
# Submitted batch job 3883205
# Submitted batch job 3883206
# Submitted batch job 3883207
# Submitted batch job 3883208
# Submitted batch job 3883209
# Submitted batch job 3883210
# Submitted batch job 3883211
# Submitted batch job 3883212
# Submitted batch job 3883213
# Submitted batch job 3883214
# Submitted batch job 3883215
# Submitted batch job 3883216
# Submitted batch job 3883217
# Submitted batch job 3883218
# Submitted batch job 3883219
# Submitted batch job 3883220
# Submitted batch job 3883221
# Submitted batch job 3883222
# Submitted batch job 3883223
# Submitted batch job 3883224
# Submitted batch job 3883225
# Submitted batch job 3883226
# Submitted batch job 3883227
# Submitted batch job 3883228
# Submitted batch job 3883229
# Submitted batch job 3883230
# Submitted batch job 3883231
# Submitted batch job 3883232
# Submitted batch job 3883233
# Submitted batch job 3883234
# Submitted batch job 3883235
# Submitted batch job 3883236
# Submitted batch job 3883237
# Submitted batch job 3883238
# Submitted batch job 3883239
# Submitted batch job 3883240
# Submitted batch job 3883241
# Submitted batch job 3883242
# Submitted batch job 3883243
# Submitted batch job 3883244
# Submitted batch job 3883245
# Submitted batch job 3883246
# Submitted batch job 3883247
# Submitted batch job 3883248
# Submitted batch job 3883249
# Submitted batch job 3883250
# Submitted batch job 3883251
# Submitted batch job 3883252
# Submitted batch job 3883253
# Submitted batch job 3883254
# Submitted batch job 3883255
# Submitted batch job 3883256
# Submitted batch job 3883257
# Submitted batch job 3883258
# Submitted batch job 3883259
# Submitted batch job 3883260
# Submitted batch job 3883261
# Submitted batch job 3883262
# Submitted batch job 3883263
# Submitted batch job 3883264
# Submitted batch job 3883265
# Submitted batch job 3883266
# Submitted batch job 3883267
# Submitted batch job 3883268
# Submitted batch job 3883269
# Submitted batch job 3883270
# Submitted batch job 3883271
# Submitted batch job 3883272
# Submitted batch job 3883273
# Submitted batch job 3883274
# Submitted batch job 3883275
# Submitted batch job 3883276
# Submitted batch job 3883277
# Submitted batch job 3883278
# Submitted batch job 3883279
# Submitted batch job 3883280
# Submitted batch job 3883281
# Submitted batch job 3883282
# Submitted batch job 3883283
# Submitted batch job 3883284
# Submitted batch job 3883285
# Submitted batch job 3883286
# Submitted batch job 3883287
# Submitted batch job 3883288
# Submitted batch job 3883289
# Submitted batch job 3883290
# Submitted batch job 3883291
# Submitted batch job 3883292
# Submitted batch job 3883293
# Submitted batch job 3883294
# Submitted batch job 3883295
# Submitted batch job 3883296
# Submitted batch job 3883297
# Submitted batch job 3883298
# Submitted batch job 3883299
# Submitted batch job 3883300
# Submitted batch job 3883301
# Submitted batch job 3883302
# Submitted batch job 3883303
# Submitted batch job 3883304
# Submitted batch job 3883305
# Submitted batch job 3883306
# Submitted batch job 3883307
# Submitted batch job 3883308
# Submitted batch job 3883309
# Submitted batch job 3883310
# Submitted batch job 3883311
# Submitted batch job 3883312
# Submitted batch job 3883313
# Submitted batch job 3883314
# Submitted batch job 3883315
# Submitted batch job 3883316
# Submitted batch job 3883317
# Submitted batch job 3883318
# Submitted batch job 3883319
# Submitted batch job 3883320
# Submitted batch job 3883321
# Submitted batch job 3883322
# Submitted batch job 3883323
# Submitted batch job 3883324
# Submitted batch job 3883325
# Submitted batch job 3883326
# Submitted batch job 3883327
# Submitted batch job 3883328
# Submitted batch job 3883329
# Submitted batch job 3883330
# Submitted batch job 3883331
# Submitted batch job 3883332
# Submitted batch job 3883333
# Submitted batch job 3883334
# Submitted batch job 3883335
# Submitted batch job 3883336
# Submitted batch job 3883337
# Submitted batch job 3883338
# Submitted batch job 3883339
# Submitted batch job 3883340
# Submitted batch job 3883341
# Submitted batch job 3883342
# Submitted batch job 3883343
# Submitted batch job 3883344
# Submitted batch job 3883345
# Submitted batch job 3883346
# Submitted batch job 3883347
# Submitted batch job 3883348
# Submitted batch job 3883349
# Submitted batch job 3883350
# Submitted batch job 3883351
# Submitted batch job 3883352
# Submitted batch job 3883353
# Submitted batch job 3883354
# Submitted batch job 3883355
# Submitted batch job 3883356
# Submitted batch job 3883357
# Submitted batch job 3883358
# Submitted batch job 3883359
# Submitted batch job 3883360
# Submitted batch job 3883361
# Submitted batch job 3883362
# Submitted batch job 3883363
# Submitted batch job 3883364
# Submitted batch job 3883365
# Submitted batch job 3883366
# Submitted batch job 3883367
# Submitted batch job 3883368
# Submitted batch job 3883369
# Submitted batch job 3883370
# Submitted batch job 3883371
# Submitted batch job 3883372
# Submitted batch job 3883373
# Submitted batch job 3883374
# Submitted batch job 3883375
# Submitted batch job 3883376
# Submitted batch job 3883377
# Submitted batch job 3883378
# Submitted batch job 3883379
# Submitted batch job 3883380
# Submitted batch job 3883381
# Submitted batch job 3883382
# Submitted batch job 3883383
# Submitted batch job 3883384
# Submitted batch job 3883385
# Submitted batch job 3883386
# Submitted batch job 3883387
# Submitted batch job 3883388
# Submitted batch job 3883389
# Submitted batch job 3883390
# Submitted batch job 3883391
# Submitted batch job 3883392
# Submitted batch job 3883393
# Submitted batch job 3883394
# Submitted batch job 3883395
# Submitted batch job 3883396
# Submitted batch job 3883397
# Submitted batch job 3883398
# Submitted batch job 3883399
# Submitted batch job 3883400
# Submitted batch job 3883401
# Submitted batch job 3883402
# Submitted batch job 3883403
# Submitted batch job 3883404
# Submitted batch job 3883405
# Submitted batch job 3883406
# Submitted batch job 3883407
# Submitted batch job 3883408
# Submitted batch job 3883409
# Submitted batch job 3883410
# Submitted batch job 3883411
# Submitted batch job 3883412
# Submitted batch job 3883413
# Submitted batch job 3883414
# Submitted batch job 3883415
# Submitted batch job 3883416
# Submitted batch job 3883417
# Submitted batch job 3883418
# Submitted batch job 3883419
# Submitted batch job 3883420
# Submitted batch job 3883421
# Submitted batch job 3883422
# Submitted batch job 3883423
# Submitted batch job 3883424
# Submitted batch job 3883425
# Submitted batch job 3883426
# Submitted batch job 3883427
# Submitted batch job 3883428
# Submitted batch job 3883429
# Submitted batch job 3883430
# Submitted batch job 3883431
# Submitted batch job 3883432
# Submitted batch job 3883433
# Submitted batch job 3883434
# Submitted batch job 3883435
# Submitted batch job 3883436
# Submitted batch job 3883437
# Submitted batch job 3883438
# Submitted batch job 3883439
# Submitted batch job 3883440
# Submitted batch job 3883441
# Submitted batch job 3883442
# Submitted batch job 3883443
# Submitted batch job 3883444
# Submitted batch job 3883445
# Submitted batch job 3883446
# Submitted batch job 3883447
# Submitted batch job 3883448
# Submitted batch job 3883449
# Submitted batch job 3883450
# Submitted batch job 3883451
# Submitted batch job 3883452
# Submitted batch job 3883453
# Submitted batch job 3883454
# Submitted batch job 3883455
# Submitted batch job 3883456
# Submitted batch job 3883457
# Submitted batch job 3883458
# Submitted batch job 3883459
# Submitted batch job 3883460
# Submitted batch job 3883461
# Submitted batch job 3883462
# Submitted batch job 3883463
# Submitted batch job 3883464
# Submitted batch job 3883465
# Submitted batch job 3883466
# Submitted batch job 3883467
# Submitted batch job 3883468
# Submitted batch job 3883469
# Submitted batch job 3883470
# Submitted batch job 3883471
# Submitted batch job 3883472
# Submitted batch job 3883473
# Submitted batch job 3883474
# Submitted batch job 3883475
# Submitted batch job 3883476
# Submitted batch job 3883477
# Submitted batch job 3883478
# Submitted batch job 3883479
# Submitted batch job 3883480
# Submitted batch job 3883481
# Submitted batch job 3883482
# Submitted batch job 3883483
# Submitted batch job 3883484
# Submitted batch job 3883485
# Submitted batch job 3883486
# Submitted batch job 3883487
# Submitted batch job 3883488
# Submitted batch job 3883489
# Submitted batch job 3883490
# Submitted batch job 3883491
# Submitted batch job 3883492
# Submitted batch job 3883493
# Submitted batch job 3883494
# Submitted batch job 3883495
# Submitted batch job 3883496
# Submitted batch job 3883497
# Submitted batch job 3883498
# Submitted batch job 3883499
# Submitted batch job 3883500
# Submitted batch job 3883501
# Submitted batch job 3883502
# Submitted batch job 3883503
# Submitted batch job 3883504
# Submitted batch job 3883505
# Submitted batch job 3883506
# Submitted batch job 3883507
# Submitted batch job 3883508
# Submitted batch job 3883509
# Submitted batch job 3883510
# Submitted batch job 3883511
# Submitted batch job 3883512
# Submitted batch job 3883513
# Submitted batch job 3883514
# Submitted batch job 3883515
# Submitted batch job 3883516
# Submitted batch job 3883517
# Submitted batch job 3883518
# Submitted batch job 3883519
# Submitted batch job 3883520
# Submitted batch job 3883521
# Submitted batch job 3883522
# Submitted batch job 3883523
# Submitted batch job 3883524
# Submitted batch job 3883525
# Submitted batch job 3883526
# Submitted batch job 3883527
# Submitted batch job 3883528
# Submitted batch job 3883529
# Submitted batch job 3883530
# Submitted batch job 3883531
# Submitted batch job 3883532
# Submitted batch job 3883533
# Submitted batch job 3883534
# Submitted batch job 3883535
# Submitted batch job 3883536
# Submitted batch job 3883537
# Submitted batch job 3883538
# Submitted batch job 3883539
# Submitted batch job 3883540
# Submitted batch job 3883541
# Submitted batch job 3883542
# Submitted batch job 3883543
# Submitted batch job 3883544
# Submitted batch job 3883545
# Submitted batch job 3883546
# Submitted batch job 3883547
# Submitted batch job 3883548
# Submitted batch job 3883549
# Submitted batch job 3883550
# Submitted batch job 3883551
# Submitted batch job 3883552
# Submitted batch job 3883553
# Submitted batch job 3883554
# Submitted batch job 3883555
# Submitted batch job 3883556
# Submitted batch job 3883557
# Submitted batch job 3883558
# Submitted batch job 3883559
# Submitted batch job 3883560
# Submitted batch job 3883561
# Submitted batch job 3883562
# Submitted batch job 3883563
# Submitted batch job 3883564
# Submitted batch job 3883565
# Submitted batch job 3883566
# Submitted batch job 3883567
# Submitted batch job 3883568
# Submitted batch job 3883569
# Submitted batch job 3883570
# Submitted batch job 3883571
# Submitted batch job 3883572
# Submitted batch job 3883573
# Submitted batch job 3883574
# Submitted batch job 3883575
# Submitted batch job 3883576
# Submitted batch job 3883577
# Submitted batch job 3883578
# Submitted batch job 3883579
# Submitted batch job 3883580
# Submitted batch job 3883581
# Submitted batch job 3883582
# Submitted batch job 3883583
# Submitted batch job 3883584
# Submitted batch job 3883585
# Submitted batch job 3883586
# Submitted batch job 3883587
# Submitted batch job 3883588
# Submitted batch job 3883589
# Submitted batch job 3883590
# Submitted batch job 3883591
# Submitted batch job 3883592
# Submitted batch job 3883593
# Submitted batch job 3883594
# Submitted batch job 3883595
# Submitted batch job 3883596
# Submitted batch job 3883597
# Submitted batch job 3883598
# Submitted batch job 3883599
# Submitted batch job 3883600
# Submitted batch job 3883601
# Submitted batch job 3883602
# Submitted batch job 3883603
# Submitted batch job 3883604
# Submitted batch job 3883605
# Submitted batch job 3883606
# Submitted batch job 3883607
# Submitted batch job 3883608
# Submitted batch job 3883609
# Submitted batch job 3883610
# Submitted batch job 3883611
# Submitted batch job 3883612
# Submitted batch job 3883613
# Submitted batch job 3883614
# Submitted batch job 3883615
# Submitted batch job 3883616
# Submitted batch job 3883617
# Submitted batch job 3883618
# Submitted batch job 3883619
# Submitted batch job 3883620
# Submitted batch job 3883621
# Submitted batch job 3883622
# Submitted batch job 3883623
# Submitted batch job 3883624
# Submitted batch job 3883625
# Submitted batch job 3883626
# Submitted batch job 3883627
# Submitted batch job 3883628
# Submitted batch job 3883629
# Submitted batch job 3883630
# Submitted batch job 3883631
# Submitted batch job 3883632
# Submitted batch job 3883633
# Submitted batch job 3883634
# Submitted batch job 3883635
# Submitted batch job 3883636
# Submitted batch job 3883637
# Submitted batch job 3883638
# Submitted batch job 3883639
# Submitted batch job 3883640
# Submitted batch job 3883641
# Submitted batch job 3883642
# Submitted batch job 3883643
# Submitted batch job 3883644
# Submitted batch job 3883645
# Submitted batch job 3883646
# Submitted batch job 3883647
# Submitted batch job 3883648
# Submitted batch job 3883649
# Submitted batch job 3883650
# Submitted batch job 3883651
# Submitted batch job 3883652
# Submitted batch job 3883653
# Submitted batch job 3883654
# Submitted batch job 3883655
# Submitted batch job 3883656
# Submitted batch job 3883657
# Submitted batch job 3883658
# Submitted batch job 3883659
# Submitted batch job 3883660
# Submitted batch job 3883661
# Submitted batch job 3883662
# Submitted batch job 3883663
# Submitted batch job 3883664
# Submitted batch job 3883665
# Submitted batch job 3883666
# Submitted batch job 3883667
# Submitted batch job 3883668
# Submitted batch job 3883669
# Submitted batch job 3883670
# Submitted batch job 3883671
# Submitted batch job 3883672
# Submitted batch job 3883673
# Submitted batch job 3883674
# Submitted batch job 3883675
# Submitted batch job 3883676
# Submitted batch job 3883677
# Submitted batch job 3883678
# Submitted batch job 3883679
# Submitted batch job 3883680
# Submitted batch job 3883681
# Submitted batch job 3883682
# Submitted batch job 3883683
# Submitted batch job 3883684
# Submitted batch job 3883685
# Submitted batch job 3883686
# Submitted batch job 3883687
# Submitted batch job 3883688
# Submitted batch job 3883689
# Submitted batch job 3883690
# Submitted batch job 3883691
# Submitted batch job 3883692
# Submitted batch job 3883693
# Submitted batch job 3883694
# Submitted batch job 3883695
# Submitted batch job 3883696
# Submitted batch job 3883697
# Submitted batch job 3883698
# Submitted batch job 3883699
# Submitted batch job 3883700
# Submitted batch job 3883701
# Submitted batch job 3883702
# Submitted batch job 3883703
# Submitted batch job 3883704
# Submitted batch job 3883705
# Submitted batch job 3883706
# Submitted batch job 3883707
# Submitted batch job 3883708
# Submitted batch job 3883709
# Submitted batch job 3883710
# Submitted batch job 3883711
# Submitted batch job 3883712
# Submitted batch job 3883713
# Submitted batch job 3883714
# Submitted batch job 3883715
# Submitted batch job 3883716
# Submitted batch job 3883717
# Submitted batch job 3883718
# Submitted batch job 3883719
# Submitted batch job 3883720
# Submitted batch job 3883721
# Submitted batch job 3883722
# Submitted batch job 3883723
# Submitted batch job 3883724
# Submitted batch job 3883725
# Submitted batch job 3883726
# Submitted batch job 3883727
# Submitted batch job 3883728
# Submitted batch job 3883729
# Submitted batch job 3883730
# Submitted batch job 3883731
# Submitted batch job 3883732
# Submitted batch job 3883733
# Submitted batch job 3883734
# Submitted batch job 3883735
# Submitted batch job 3883736
# Submitted batch job 3883737
# Submitted batch job 3883738
# Submitted batch job 3883739
# Submitted batch job 3883740
# Submitted batch job 3883741
# Submitted batch job 3883742
# Submitted batch job 3883743
# Submitted batch job 3883744
# Submitted batch job 3883745
# Submitted batch job 3883746
# Submitted batch job 3883747
# Submitted batch job 3883748
# Submitted batch job 3883749
# Submitted batch job 3883750
# Submitted batch job 3883751
# Submitted batch job 3883752
# Submitted batch job 3883753
# Submitted batch job 3883754
# Submitted batch job 3883755
# Submitted batch job 3883756
# Submitted batch job 3883757
# Submitted batch job 3883758
# Submitted batch job 3883759
# Submitted batch job 3883760
# Submitted batch job 3883761
# Submitted batch job 3883762
# Submitted batch job 3883763
# Submitted batch job 3883764
# Submitted batch job 3883765
# Submitted batch job 3883766
# Submitted batch job 3883767
# Submitted batch job 3883768
# Submitted batch job 3883769
# Submitted batch job 3883770
# Submitted batch job 3883771
# Submitted batch job 3883772
# Submitted batch job 3883773
# Submitted batch job 3883774
# Submitted batch job 3883775
# Submitted batch job 3883776
# Submitted batch job 3883777
# Submitted batch job 3883778
# Submitted batch job 3883779
# Submitted batch job 3883780
# Submitted batch job 3883781
# Submitted batch job 3883782
# Submitted batch job 3883783
# Submitted batch job 3883784
# Submitted batch job 3883785
# Submitted batch job 3883786
# Submitted batch job 3883787
# Submitted batch job 3883788
# Submitted batch job 3883789
# Submitted batch job 3883790
# Submitted batch job 3883791
# Submitted batch job 3883792
# Submitted batch job 3883793
# Submitted batch job 3883794
# Submitted batch job 3883795
# Submitted batch job 3883796
# Submitted batch job 3883797
# Submitted batch job 3883798
# Submitted batch job 3883799
# Submitted batch job 3883800
# Submitted batch job 3883801
# Submitted batch job 3883802
# Submitted batch job 3883803
# Submitted batch job 3883804
# Submitted batch job 3883805
# Submitted batch job 3883806
# Submitted batch job 3883807
# Submitted batch job 3883808
# Submitted batch job 3883809
# Submitted batch job 3883810
# Submitted batch job 3883811
# Submitted batch job 3883812
# Submitted batch job 3883813
# Submitted batch job 3883814
# Submitted batch job 3883815
# Submitted batch job 3883816
# Submitted batch job 3883817
# Submitted batch job 3883818
# Submitted batch job 3883819
# Submitted batch job 3883820
# Submitted batch job 3883821
# Submitted batch job 3883822
# Submitted batch job 3883823
# Submitted batch job 3883824
# Submitted batch job 3883825
# Submitted batch job 3883826
# Submitted batch job 3883827
# Submitted batch job 3883828
# Submitted batch job 3883829
# Submitted batch job 3883830
# Submitted batch job 3883831
# Submitted batch job 3883832
# Submitted batch job 3883833
# Submitted batch job 3883834
# Submitted batch job 3883835
# Submitted batch job 3883836
# Submitted batch job 3883837
# Submitted batch job 3883838
# Submitted batch job 3883839
# Submitted batch job 3883840
# Submitted batch job 3883841
# Submitted batch job 3883842
# Submitted batch job 3883843
# Submitted batch job 3883844
# Submitted batch job 3883845
# Submitted batch job 3883846
# Submitted batch job 3883847
# Submitted batch job 3883848
# Submitted batch job 3883849
# Submitted batch job 3883850
# Submitted batch job 3883851
# Submitted batch job 3883852
# Submitted batch job 3883853
# Submitted batch job 3883854
# Submitted batch job 3883855
# Submitted batch job 3883856
# Submitted batch job 3883857
# Submitted batch job 3883858
# Submitted batch job 3883859
# Submitted batch job 3883860
# Submitted batch job 3883861
# Submitted batch job 3883862
# Submitted batch job 3883863
# Submitted batch job 3883864
# Submitted batch job 3883865
# Submitted batch job 3883866
# Submitted batch job 3883867
# Submitted batch job 3883868
# Submitted batch job 3883869
# Submitted batch job 3883870
# Submitted batch job 3883871
# Submitted batch job 3883872
# Submitted batch job 3883873
# Submitted batch job 3883874
# Submitted batch job 3883875
# Submitted batch job 3883876
# Submitted batch job 3883877
# Submitted batch job 3883878
# Submitted batch job 3883879
# Submitted batch job 3883880
# Submitted batch job 3883881
# Submitted batch job 3883882
# Submitted batch job 3883883
# Submitted batch job 3883884
# Submitted batch job 3883885
# Submitted batch job 3885566
# Submitted batch job 3885567
# Submitted batch job 3885568
# Submitted batch job 3885569
# Submitted batch job 3885570
# Submitted batch job 3885571
# Submitted batch job 3885572
# Submitted batch job 3885573
# Submitted batch job 3885574
# Submitted batch job 3885575
# Submitted batch job 3885576
# Submitted batch job 3885577
# Submitted batch job 3885578
# Submitted batch job 3885579
# Submitted batch job 3885580
# Submitted batch job 3885581
# Submitted batch job 3885582
# Submitted batch job 3885583
# Submitted batch job 3885584
# Submitted batch job 3885585
# Submitted batch job 3885586
# Submitted batch job 3885587
# Submitted batch job 3885588
# Submitted batch job 3885589
# Submitted batch job 3885590
# Submitted batch job 3885591
# Submitted batch job 3885592
# Submitted batch job 3885593
# Submitted batch job 3885594
# Submitted batch job 3885595
# Submitted batch job 3885596
# Submitted batch job 3885597
# Submitted batch job 3885598
# Submitted batch job 3885599
# Submitted batch job 3885600
# Submitted batch job 3885601
# Submitted batch job 3885602
# Submitted batch job 3885603
# Submitted batch job 3885604
# Submitted batch job 3885605
# Submitted batch job 3885606
# Submitted batch job 3885607
# Submitted batch job 3885608
# Submitted batch job 3885609
# Submitted batch job 3885610
# Submitted batch job 3885611
# Submitted batch job 3885612
# Submitted batch job 3885613
# Submitted batch job 3885614
# Submitted batch job 3885615
# Submitted batch job 3885616
# Submitted batch job 3885617
# Submitted batch job 3885618
# Submitted batch job 3885619
# Submitted batch job 3885620
# Submitted batch job 3885621
# Submitted batch job 3885622
# Submitted batch job 3885623
# Submitted batch job 3885624
# Submitted batch job 3885625
# Submitted batch job 3885626
# Submitted batch job 3885627
# Submitted batch job 3885628
# Submitted batch job 3885629
# Submitted batch job 3885630
# Submitted batch job 3885631
# Submitted batch job 3885632
# Submitted batch job 3885633
# Submitted batch job 3885634
# Submitted batch job 3885635
# Submitted batch job 3885636
# Submitted batch job 3885637
# Submitted batch job 3885638
# Submitted batch job 3885639
# Submitted batch job 3885640
# Submitted batch job 3885641
# Submitted batch job 3885642
# Submitted batch job 3885643
# Submitted batch job 3885644
# Submitted batch job 3885645
# Submitted batch job 3885646
# Submitted batch job 3885647
# Submitted batch job 3885648
# Submitted batch job 3885649
# Submitted batch job 3885650
# Submitted batch job 3885651
# Submitted batch job 3885652
# Submitted batch job 3885653
# Submitted batch job 3885654
# Submitted batch job 3885655
# Submitted batch job 3885656
# Submitted batch job 3885657
# Submitted batch job 3885658
# Submitted batch job 3885659
# Submitted batch job 3885660
# Submitted batch job 3885661
# Submitted batch job 3885662
# Submitted batch job 3885663
# Submitted batch job 3885664
# Submitted batch job 3885665
# Submitted batch job 3885666
# Submitted batch job 3885667
# Submitted batch job 3885668
# Submitted batch job 3885669
# Submitted batch job 3885670
# Submitted batch job 3885671
# Pipeline Step 5 complete

# %%
n_expected_outputs = len(dt_arr_di_case_d.keys()) + len(dt_arr_di_case_c.keys()) + len(dt_arr_di_case_b.keys())
n_output_fps = len([x for x in dst_p.rglob("*.tif")])

assert(n_expected_outputs == n_output_fps)

# %% [markdown]
# # Pipeline Complete!
