# %%
import re
from datetime import datetime

import rasterio
import xarray as xr
import rioxarray
import dask
import pandas as pd

from eda import list_geotiffs
from config import DAILY_BEAUFORT_DIR, DAILY_CHUKCHI_DIR, SCRATCH_DIR, BEAUFORT_NETCDF_DIR
from luts import ice_years

# %%
import netCDF4

# %%
from netCDF4 import Dataset
ds = Dataset(BEAUFORT_NETCDF_DIR / "beaufort_sea_daily_slie_1997-98.nc")
ds
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     crs: EPSG:3338
#     dimensions(sizes): x(9556), y(3300), time(260)
#     variables(dimensions): float64 x(x), float64 y(y), int64 spatial_ref(), uint8 slie(time, y, x), int64 time(time)
#     groups:

# %%
ds.variables["time"].units
# Out:
# 'days since 1996-10-27 00:00:00'

# %%
ds.variables["time"].calendar
# Out:
# 'proleptic_gregorian'

# %%
xds = xr.open_dataset(BEAUFORT_NETCDF_DIR / "beaufort_sea_daily_slie_1997-98.nc")
xds.time
# Out:
# <xarray.DataArray 'time' (time: 254)> Size: 2kB
# array(['1997-11-10T00:00:00.000000000', '1997-11-11T00:00:00.000000000',
#        '1997-11-12T00:00:00.000000000', ..., '1998-07-19T00:00:00.000000000',
#        '1998-07-20T00:00:00.000000000', '1998-07-21T00:00:00.000000000'],
#       dtype='datetime64[ns]')
# Coordinates:
#   * time     (time) datetime64[ns] 2kB 1997-11-10 1997-11-11 ... 1998-07-21

# %%
ds.time[0]
# Out:
# <xarray.DataArray 'time' ()> Size: 8B
# array('1996-10-27T00:00:00.000000000', dtype='datetime64[ns]')
# Coordinates:
#     time     datetime64[ns] 8B 1996-10-27

# %%
ds.sel(band=1, time="1996-12-31")

# %%
ds.sel(time="1996-12-31").slie.plot()
